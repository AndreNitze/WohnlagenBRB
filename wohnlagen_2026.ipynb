# %% [markdown]
# # Datenvorbereitung
# Zunächst werden für alle gewünschten Einflussfaktoren die Daten beschafft und in ein CSV-Format mit lat/lon oder GeoJSON-Geoemtry gebracht, sodass zu allen Adressen die gewünschten Eigenschaften vorliegen.

# %%
import warnings

warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
from shapely.geometry import box

import helper
from importlib import reload

reload(helper)
from helper import load_geocsv, s

EPSG_4326 = "EPSG:4326"

# BBOX für Brandenburg an der Havel
CITY_BOUNDING_BOX = box(12.3120236786, 52.2938432979, 12.7562682548, 52.5594777244)

#  Stadtzentrum für Brandenburg an der Havel
CITY_CENTER = (52.4116351153561, 12.556331280534392) # Jahrtausendbrücke
#CITY_CENTER = 52.40905351242835, 12.517490967204653 # Visuelles Zentrum, damit periphere Cluster sichtbar bleiben

# %% [markdown]
# ## Adressen einlesen
# Alle Adressen des Zielgebiets als CSV in einen GeoDataFrame einlesen.

# %%
gdf = load_geocsv("out/adressen_mit_zentrum_routen.csv")

# Adressen ohne Geometrie entfernen
gdf = gdf[~gdf.geometry.isna()].copy()

# Variante nur für urbanes Zentrum: Filter auf Adressen mit Distanz < 7500 m
# Auskommentieren für ganzen Datensatz!
# gdf = gdf.loc[gdf["distance_m"] < 7500].copy()

# %% [markdown]
# ## Explorative Datenanalyse

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns           # nur für schönere Plots
from helper import load_geocsv, make_merge_addr

# Eindeutigen Merge-baren String aus Adresse erzeugen
gdf["Adresse_merge"] = gdf.apply(make_merge_addr, axis=1)

gdf = gdf.rename(columns={"geojson": "center_route",
                                    "distance_m" : "center_distance"})

# Ein paar unbenötigte Spalten entfernen
gdf = gdf.drop(columns=["index_right", "duration_s", "display_name", "type", "category", "Adresse_query"], errors="ignore")

# Blockzuordnung aus Blockgrenzen ergänzen
gdf_blockgrenzen = gpd.read_file("data/2026-02-12-Blockgrenzen.gpkg")[["BLOCK", "geometry"]].rename(columns={"BLOCK": "block"})
gdf_blockgrenzen = gdf_blockgrenzen.to_crs(gdf.crs)
gdf = gdf.drop(columns=["index_right", "block"], errors="ignore")
gdf = gpd.sjoin(
    gdf,
    gdf_blockgrenzen,
    how="left",
    predicate="within",
)
gdf = gdf.drop(columns=["index_right"], errors="ignore")

# Histogramm der Distanzen zum Zentrum
plt.figure(figsize=(6,3))
sns.histplot(gdf["center_distance"], bins=60, kde=False)
plt.title("Verteilung der Fußentfernung zum Zentrum")
plt.xlabel("Distanz (Meter)")
plt.ylabel("Häufigkeit")
plt.show()
print(gdf.shape)

# %% [markdown]
# ## Daten bereinigen

# %%
print(gdf.shape)
# Dubletten aus Adressen entfernen
dups = gdf["Adresse_merge"].value_counts()
dups = dups[dups > 1]
print(f"{len(dups)} doppelte Adressen gefunden")
print(dups.head())

# Ersten Treffer behalten
gdf = gdf.sort_values("Adresse_merge").drop_duplicates("Adresse_merge", keep="first")
print(gdf.shape)

# %%
# Gebäudetypologie ergänzen
gdf_typologie = pd.read_csv("data/Gebaeudetypologie.csv")

# Quellen sind je nach Datenstand unterschiedlich benannt; robust auflösen.
type_source_col = next(
    (c for c in ["Typologie", "typologie", "GEBTYPGROESSE"] if c in gdf_typologie.columns),
    None,
)
age_source_col = next(
    (c for c in ["Baualtersklassen_Zensus", "Baualtersklassen_Stadt"] if c in gdf_typologie.columns),
    None,
)
if type_source_col is None:
    raise KeyError("Keine Typologiespalte gefunden (erwartet: Typologie oder GEBTYPGROESSE).")
if age_source_col is None:
    raise KeyError("Keine Baualtersklassenspalte gefunden.")

rename_map = {
    type_source_col: "building_type",
    age_source_col: "building_age_class",
}
gdf_typologie = gdf_typologie.rename(columns=rename_map)

if "Baualtersklassen_Stadt" in gdf_typologie.columns and age_source_col != "Baualtersklassen_Stadt":
    gdf_typologie["building_age_class"] = gdf_typologie["building_age_class"].fillna(gdf_typologie["Baualtersklassen_Stadt"])

# Fallback: Wenn Typologie unbekannt ist, Gebäudetyp (EFH/ZFH/ZWH) als freistehend mappen.
fallback_source_col = next(
    (c for c in ["Gebäudetyp", "Gebaeudetyp", "gebaeudetyp"] if c in gdf_typologie.columns),
    None,
)

fallback_assigned_count = 0
if fallback_source_col is not None:
    def _map_freistehend_from_gebaeudetyp(value):
        text = str(value).strip().lower()
        if text in {"", "nan", "none"}:
            return None
        text = (
            text.replace("ä", "ae")
            .replace("ö", "oe")
            .replace("ü", "ue")
            .replace("ß", "ss")
        )
        if "efh" in text or "einfamil" in text:
            return "Freistehendes EFH"
        if "zfh" in text or "zwh" in text or "zweifamil" in text:
            return "Freistehendes ZWH"
        return None

    typology_unknown_mask = gdf_typologie["building_type"].astype(str).str.strip().str.lower().isin({"", "nan", "none", "unbekannt"})
    fallback_values = gdf_typologie[fallback_source_col].map(_map_freistehend_from_gebaeudetyp)
    fallback_mask = typology_unknown_mask & fallback_values.notna()
    fallback_assigned_count = int(fallback_mask.sum())
    gdf_typologie.loc[fallback_mask, "building_type"] = fallback_values.loc[fallback_mask]

gdf_typologie["Adresse_merge"] = gdf_typologie.apply(make_merge_addr, axis=1)
gdf_typologie = gdf_typologie.sort_values("Adresse_merge").drop_duplicates("Adresse_merge", keep="first")

typologie_attributes = ["building_type", "building_age_class"]
gdf = gdf.drop(columns=typologie_attributes + ["is_freistehend_building"], errors="ignore")
gdf = pd.merge(
    gdf,
    gdf_typologie[["Adresse_merge"] + typologie_attributes],
    on="Adresse_merge",
    how="left",
    validate="one_to_one",
)
typology_missing = int(gdf["building_type"].isna().sum())
gdf[typologie_attributes] = gdf[typologie_attributes].fillna("unbekannt")

FREISTEHENDE_BUILDING_TYPES = {
    "Freistehendes EFH",
    "Freistehendes ZWH",
    "Freistehendes ZFH",
}
gdf["is_freistehend_building"] = gdf["building_type"].isin(FREISTEHENDE_BUILDING_TYPES)

print(f"Fehlende Typologien nach Merge: {typology_missing}")
print(f"Fallback-Zuordnungen über Gebäudetyp: {fallback_assigned_count}")
print(gdf["building_type"].value_counts(dropna=False).head())
print(gdf["is_freistehend_building"].value_counts(dropna=False))

# %% [markdown]
# ## Einzelhandel
# Separates Skript ```einzelhandel-adressen.py``` ausfühen, um Datei "adressen_mit_einzelhandel.csv" zu erzeugen.
# Durch fußläufiges Routing berechnete Faktoren:
# - Anzahl von Einkaufsmöglichkeiten im Umkreis von 500 m (Anforderung AK MSP: mind. 1)
# - Geringste Distanz zum nächsten Einzelhandel

# %%
import seaborn as sns, matplotlib.pyplot as plt

# Lade vorberechnete Einzelhandel-Faktoren
gdf_retail = load_geocsv("out/adressen_mit_einzelhandel_routen.csv")

# Merge mit Haupt-GDF
gdf_retail["Adresse_merge"] = gdf_retail.apply(make_merge_addr, axis=1)
gdf_retail = gdf_retail.sort_values("Adresse_merge").drop_duplicates("Adresse_merge", keep="first")

dups = gdf_retail["Adresse_merge"].value_counts()
print(dups[dups > 1])

einzelhandel_attribute = ["einzelhandel_route","einzelhandel_min_distance", "einzelhandel_500m_count"]

gdf = pd.merge(
    gdf,
    gdf_retail[["Adresse_merge"] + einzelhandel_attribute],
    on="Adresse_merge",
    how="left",
    validate="one_to_many"
)
print(gdf.shape)
print(gdf[["Adresse_merge", "einzelhandel_min_distance"]].head())

print(gdf.shape)

# Speicher freigeben
del(gdf_retail)

# %%
# Verteilung Distanz zum nächsten Markt
print(gdf.columns)
sns.histplot(gdf["einzelhandel_min_distance"].dropna(), bins=40, kde=False)
plt.title("Distanz zum nächsten Lebensmittelmarkt")
plt.xlabel("Meter Fußweg"); plt.ylabel("Adressen")
plt.show()

# Scatter Zentralität vs. Nahversorgung
sns.scatterplot(x="center_distance", y="einzelhandel_min_distance", data=gdf, alpha=.3)
plt.xlabel("Distanz Zentrum (m)"); plt.ylabel("Distanz nächster Markt (m)")
plt.show()

# %% [markdown]
# ## Lärmbelastung
# Siehe ```laerm.ipynb``` zur Erzeugung, ansonsten einfach ```data/adressen_mit_laerm.csv``` verwenden und per Spalte 'geometry' verschneiden.
#
# Definition Lärm-Index:
# - NaN / leer: kein gemessener Straßenlärm
# - 0: 55 - 59 dB
# - 1: 60 - 64 dB
# - 2: 65 - 69 dB
# - 3: 70 - 74 dB
# - 4: >= 75 db

# %%
gdf_laerm_karte = load_geocsv("out/adressen_mit_laerm.csv")
print(gdf_laerm_karte.shape)
print(gdf.shape)

# Merge des Lärmindex mit Haupt-GDF
gdf_laerm_karte["Adresse_merge"] = gdf_laerm_karte.apply(make_merge_addr, axis=1)
gdf_laerm_karte["laerm_index_tag"] = gdf_laerm_karte["Laerm_index_tag"].fillna(-0.1) # lowercase

# Deduplicate, im Zweifel nimm den lautesten Wert
gdf_laerm_karte = (
    gdf_laerm_karte
    .sort_values("laerm_index_tag", ascending=False)
    .drop_duplicates("Adresse_merge", keep="first")
)

laerm_attribute = ["laerm_index_tag"]
gdf = pd.merge(
    gdf,
    gdf_laerm_karte[["Adresse_merge"] + laerm_attribute],
    on="Adresse_merge",
    how="left",
    validate="one_to_many"
)

#print(gdf.columns)
print(gdf.shape)

# %% [markdown]
# ## ÖPNV-Haltestellen
#
# Die Qualität des ÖPNV wird anhand der Fußläufigkeit zur nächsten Haltestelle definiert.
#
# Die Häufigkeit von Abfahrten (Headway) wurde zwar berechnet (s. `public-transport.ipynb`), ist aber in der aktuellen Form noch kein verlässlicher Indikator. Stattdessen wird die Anzahl der verkehrenden Linien an den Haltestellen als Proxy-Variable für die Frequentierung der Haltestelle verwendet: **Je mehr Linien an einer Haltestelle, desto höher die Qualität der ÖPNV-Anbindung.**
#
# Die Daten dafür stammen vom Verkehrsverbund Berlin-Brandenburg (VBB), Lizenz: CC BY 4.0, [zu den Daten](https://unternehmen.vbb.de/digitale-services/datensaetze) und der Stadt Brandenburg an der Havel ("2026_Haltestellen.csv").
#
# Vorausgesetzte Datensätze:
# - `out/adressen_mit_haltestellen_routen.csv`, der die Routen zu den Haltestellen und Anzahl von Haltestellen im Radius 500m und 800m enthält.
# - `out/haltestellen_geocoded.csv`, der die Haltestellen mit Geokoordinaten und der Anzahl der dort verkehrenden Linien enthält.

# %%
import pandas as pd
import geopandas as gpd

gdf_haltestellen = load_geocsv("out/adressen_mit_haltestellen_routen.csv")
gdf_haltestellen["Adresse_merge"] = gdf_haltestellen.apply(make_merge_addr, axis=1)
gdf_haltestellen = gdf_haltestellen.drop_duplicates("Adresse_merge").copy()
gdf_haltestellen = gdf_haltestellen.rename(columns={"Anzahl der Linien": "haltestellen_linien_count", "linien_count": "haltestellen_linien_count"})

print("gdf_haltestellen shape:", gdf_haltestellen.shape)
print("gdf shape (vor Merge):", gdf.shape)

# Merge haltestellen attributes into main GeoDataFrame
haltestellen_attribute = ["haltestellen_route", "haltestellen_min_distance", "haltestellen_target_name", "haltestellen_count_within_500m", "haltestellen_count_within_800m", "haltestellen_linien_count"]
gdf = pd.merge(
    gdf,
    gdf_haltestellen[["Adresse_merge"] + haltestellen_attribute],
    on="Adresse_merge",
    how="left",
    validate="one_to_one"
)

print("gdf shape (nach Merge):", gdf.shape)

# %% [markdown]
# ## Begrenzung durch dauerhafte Barrieren
# Als zusätzlicher Indikator wird berechnet, ob eine Adresse durch eine Bahnlinie vom Stadtzentrum getrennt ist. Damit wird abgebildet, ob eine Adresse trotz Nähe zum Zentrum durch eine Barriere erschwerten Zugang hat (z. B., durch Wartezeiten an Bahnübergängen).
#
# Die Variable z_rail_penalty modelliert im Modell später die Barrierewirkung von Bahnlinien als festen, moderaten Mobilitätsabschlag für Adressen, die vom Zentrum aus gesehen hinter einer Bahnlinie liegen.

# %%
import osmnx as ox
from shapely.geometry import LineString
# Schritt 1: Bahnlinien von OSM laden
place = "Brandenburg an der Havel, Germany"

# Eisenbahnlinien holen
rails = ox.features_from_place(
    place,
    tags={"railway": True}  # includes rail, light_rail, tram, etc.
)

# nur Schienenverkehr (keine Haltestellen)
rails = rails[rails["railway"].isin(["rail"])]
gdf.crs = EPSG_4326
rails.crs = EPSG_4326

# Schritt 2: Fußĺäufige Routen zum Stadtzentrum auf Schnittpunkt mit Bahnlinie prüfen und im Datensatz speichern
def route_crosses_rail(route_geojson_str, rail_geom):
    if not isinstance(route_geojson_str, str):
        return False

    try:
        geo = json.loads(route_geojson_str)
    except:
        return False

    if geo.get("type") != "LineString":
        return False

    # Koordinaten (lon, lat) -> Shapely LineString nutzen
    coords = geo["coordinates"]
    line = LineString(coords)

    # Schnitt-Test
    return line.intersects(rail_geom)

rail_union = rails.union_all()
gdf["behind_rail_from_center"] = gdf["center_route"].apply(
    lambda r: int(route_crosses_rail(r, rail_union))
)

print(gdf.shape)

# %%
import json
import folium

# 10 zufällige Adressen ziehen
sample_gdf = gdf.sample(10, random_state=42)

center_lat, center_lon = CITY_CENTER  # CITY_CENTER ist [lat, lon]
center_point = (center_lat, center_lon)
m = folium.Map(location=CITY_CENTER, zoom_start=13, tiles="cartodbpositron")

# Zentrum markieren
folium.Marker(
    location=CITY_CENTER,
    tooltip="Stadtzentrum",
    icon=folium.Icon(color="red", icon="star")
).add_to(m)

# Route + Marker je Adresse
for idx, row in sample_gdf.iterrows():
    if pd.isna(row["lat"]) or pd.isna(row["lon"]):
        continue

    addr_point = (row["lat"], row["lon"])
    behind_flag = row.get("behind_rail_from_center", None)

    tooltip = f"Adresse {idx}<br>behind_rail_from_center: {behind_flag}"

    # Route zum Zentrum (GeoJSON)
    route_json = row.get("center_route")

    if isinstance(route_json, str):
        try:
            route_geo = json.loads(route_json)

            if route_geo.get("type") == "LineString":
                # GeoJSON Koordinaten sind (lon, lat)
                coords = [(c[1], c[0]) for c in route_geo["coordinates"]]

                folium.PolyLine(
                    locations=coords,
                    color="blue",
                    weight=4,
                    opacity=0.7,
                    tooltip=f"Route zu Adresse {idx}"
                ).add_to(m)

        except Exception as e:
            print(f"Fehler beim Zeichnen der Route für Adresse {idx}: {e}")

    # Adressmarker
    folium.CircleMarker(
        location=addr_point,
        radius=4,
        color="blue",
        fill=True,
        fill_opacity=0.8,
        tooltip=folium.Tooltip(tooltip)
    ).add_to(m)

# Bahnlinien-Layer
bahn_layer = folium.FeatureGroup(name="Bahnlinien (OSM)", show=True)

for _, row in rails.iterrows():
    geom = row.geometry
    if geom is None:
        continue

    if geom.geom_type == "LineString":
        coords = [(y, x) for x, y in geom.coords]
        folium.PolyLine(
            locations=coords,
            color="darkred",
            weight=4,
            opacity=0.8
        ).add_to(bahn_layer)

    elif geom.geom_type == "MultiLineString":
        for part in geom:
            coords = [(y, x) for x, y in part.coords]
            folium.PolyLine(
                locations=coords,
                color="darkred",
                weight=4,
                opacity=0.8
            ).add_to(bahn_layer)

bahn_layer.add_to(m)

print(gdf.shape)
#m

# %% [markdown]
# # Visualisierung zentraler Indikatoren
# Alle Einflussfaktoren (Supermärkte, Ärzte, Schulen etc.) werden zur Plausibilitätsprüfung auf einer Karte visualisiert.

# %%
import folium
import branca.colormap as cm
from helper import add_markers_from_csv, add_medcenter_markers, STRASSENNAME, HAUSNUMMER, HAUSNUMMERZUSATZ

m = folium.Map(location=CITY_CENTER, zoom_start=13, tiles="cartodbpositron")


# Add layer markers
add_markers_from_csv(map_obj=m, csv_path="out/einzelhandel_geocoded.csv", color="blue", icon="shopping-cart", layer_name="Einzelhandel")
add_markers_from_csv(map_obj=m, csv_path="out/haltestellen_geocoded.csv", color="lightgray", icon="bus", layer_name="Haltestellen")

# Lärmindex aus dem Geopackage
gdf_laerm_karte = gpd.read_file("data/laerm.gpkg", layer="laerm")
gdf_laerm_karte = gdf_laerm_karte.clip(CITY_BOUNDING_BOX)
value_column = "isov1"
min_val = gdf_laerm_karte[value_column].min()
max_val = gdf_laerm_karte[value_column].max()
colormap = cm.LinearColormap(colors=["green", "yellow", "red"], vmin=min_val, vmax=max_val)
colormap.caption = "Lärmpegel (LDEN in dB)"

# Alle Adressen als Punkte
adress_layer = folium.FeatureGroup(name="Wohnadressen", show=False)
for _, row in gdf.iterrows():
    if pd.notna(row["lat"]) and pd.notna(row["lon"]):
        strasse = s(row.get(STRASSENNAME))
        hsnr = s(row.get(HAUSNUMMER))
        hsnrzus = s(row.get(HAUSNUMMERZUSATZ))

        tooltip = strasse + " " + hsnr

        adressen_map = folium.CircleMarker(
            location=[row["lat"], row["lon"]],
            radius=3,
            color="violet",
            fill=True,
            fill_opacity=0.6,
            tooltip=tooltip
        ).add_to(adress_layer)
adress_layer.add_to(m)

def style_function(feature):
    value = feature["properties"][value_column]
    return {
        "fillColor": colormap(value),
        "color": "black",
        "weight": 0.3,
        "fillOpacity": 0.2
    }

laerm_layer = folium.FeatureGroup(name="Lärmkarte (LDEN 2022)")
folium.GeoJson(
    gdf_laerm_karte,
    style_function=style_function,
).add_to(laerm_layer)
laerm_layer.add_to(m)
colormap.add_to(m)

# Bahnlinien layer hinzufügen
bahn_layer = folium.FeatureGroup(name="Bahnlinien", show=True)

for _, row in rails.iterrows():
    geom = row.geometry
    if geom is None:
        continue

    if geom.geom_type == "LineString":
        coords = [(y, x) for x, y in geom.coords]
        folium.PolyLine(
            locations=coords,
            color="darkred",
            weight=4,
            opacity=0.8
        ).add_to(bahn_layer)

    elif geom.geom_type == "MultiLineString":
        for part in geom:
            coords = [(y, x) for x, y in part.coords]
            folium.PolyLine(
                locations=coords,
                color="darkred",
                weight=4,
                opacity=0.8
            ).add_to(bahn_layer)

bahn_layer.add_to(m)

# Wohnadressen nach "cluster_kmeans" farb-codiert oben drauf

# Schaltbare Layer
folium.LayerControl(collapsed=False).add_to(m)
del gdf_laerm_karte  # Speicher freigeben
print(gdf.shape)
m

# %% [markdown]
# # Scoring / Punktesystem
# Hier werden z-Werte zu alle **Einflussfaktoren** gebildet, um die Abweichung einer Ausprägung vom Standard (im betrachteten Gebiet) zu erfassen. Weiterhin werden die **Gewichte** festgelegt, mit denen die Faktoren in die Wohnlagenbewertung eingehen.

# %%
import numpy as np
from scipy.stats import zscore

# ---------------------------------------
# 1) Numerische & binäre Features
# ---------------------------------------
numeric_features = (
        ["center_distance"] +
        haltestellen_attribute +
        einzelhandel_attribute +
        laerm_attribute 
        )

#binary_features = ["behind_rail_from_center"]

# Masken nur auf numerische Daten!
mask_all = gdf[numeric_features].notna().all(axis=1)

# ---------------------------------------
# 2) Z-Scores für numerische Variablen
#    (immer: hoch = gut!)
# ---------------------------------------
def safe_z(x):
    z = zscore(x)
    return np.where(np.isfinite(z), z, 0)

# Zentralität
gdf.loc[mask_all, "z_centrality"] = -safe_z(gdf.loc[mask_all, "center_distance"])

# Einzelhandel
gdf.loc[mask_all, "z_einzelhandel_distance"]    = -safe_z(gdf.loc[mask_all, "einzelhandel_min_distance"])
gdf.loc[mask_all, "z_einzelhandel_near_500"]    =  safe_z(gdf.loc[mask_all, "einzelhandel_500m_count"])

# Lärm
gdf.loc[mask_all, "z_laerm_index_tag"]          = -safe_z(gdf.loc[mask_all, "laerm_index_tag"])
# Einseitiger Strafterm: nur überdurchschnittlicher Lärm führt zu Abzug
# Wichtig: Im Gesamt-Score geht Lärm nur ueber z_noise_penalty ein (kein Doppelcount)
gdf.loc[mask_all, "z_noise_penalty"]           = -0.30 * np.clip(safe_z(gdf.loc[mask_all, "laerm_index_tag"]), 0, None)

# Mobilität
gdf.loc[mask_all, "z_haltestelle_distance"]     = -safe_z(gdf.loc[mask_all, "haltestellen_min_distance"])
gdf.loc[mask_all, "z_haltestellen_count_within_500m"] =  safe_z(gdf.loc[mask_all, "haltestellen_count_within_500m"])
gdf.loc[mask_all, "z_haltestellen_linien_count"] =  safe_z(gdf.loc[mask_all, "haltestellen_linien_count"])
#gdf.loc[mask_all, "z_headway_score"]            = -safe_z(gdf.loc[mask_all, "headway_avg"]) # vorläufig nicht in der Bewertung
#gdf["z_rail_penalty"] = -0.3 * gdf["behind_rail_from_center"] # Leichte Strafe, wenn durch Bahnlinie vom Zentrum getrennt

# ---------------------------------------
# 3) Score-Dimensionen (alle Summen = 1.0)
# ---------------------------------------
### 3.1 Zentralität (1 Dimension, Summe = 1.0)
mask_mm_central = gdf["center_distance"].notna()
gdf.loc[mask_mm_central, "score_zentralitaet"] = gdf.loc[mask_mm_central, "z_centrality"]


### 3.2 Versorgung (Summe = 1.0)
mask_mm_versorgung = gdf[[
    "einzelhandel_min_distance",
    "einzelhandel_500m_count"
]].notna().all(axis=1)

gdf.loc[mask_mm_versorgung, "score_versorgung"] = (
        0.50 * gdf.loc[mask_mm_versorgung, "z_einzelhandel_distance"]
        + 0.50 * gdf.loc[mask_mm_versorgung, "z_einzelhandel_near_500"]
)

### 3.3 Mobilität (Summe = 1.0)
mask_mm_mobilitaet = gdf[[
    "haltestellen_min_distance",
    "haltestellen_count_within_500m",
    "haltestellen_linien_count"
]].notna().all(axis=1)

gdf.loc[mask_mm_mobilitaet, "score_mobilitaet"] = (
        (1.0 / 3.0) * gdf.loc[mask_mm_mobilitaet, "z_haltestelle_distance"]
       # + 0.40 * gdf.loc[mask_mm_mobilitaet, "z_rail_penalty"]
        + (1.0 / 3.0) * gdf.loc[mask_mm_mobilitaet, "z_haltestellen_count_within_500m"]
        + (1.0 / 3.0) * gdf.loc[mask_mm_mobilitaet, "z_haltestellen_linien_count"]
)


### 3.4 Umwelt (Summe = 1.0)
# Umwelt (Summe = 1.0)
mask_mm_umwelt = gdf[[
    "laerm_index_tag",
]].notna().all(axis=1)

gdf.loc[mask_mm_umwelt, "score_umwelt"] = (
        + 1.0 * gdf.loc[mask_mm_umwelt, "z_laerm_index_tag"]
)  # Diagnosewert; score_total nutzt stattdessen z_noise_penalty (kein Doppelcount)

# ---------------------------------------
# 4) Gesamt-Score (alle Dimensionen)
# ---------------------------------------
score_all_vars = [
    "score_zentralitaet",
    "score_versorgung",
    "score_mobilitaet"
]
#### ANPASSUNG GEWICHTE HIER: ####

mask_all_scores = gdf[score_all_vars + ["z_noise_penalty"]].notna().all(axis=1)
gdf.loc[mask_all_scores, "score_total"] = (
        (1.0 / 3.0) * gdf.loc[mask_all_scores, "score_zentralitaet"]
        + (1.0 / 3.0) * gdf.loc[mask_all_scores, "score_versorgung"]
        + (1.0 / 3.0) * gdf.loc[mask_all_scores, "score_mobilitaet"]
        + gdf.loc[mask_all_scores, "z_noise_penalty"]  # separater Laerm-Malus
)

print("Anzahl gültiger Gesamt-Scores:", gdf["score_total"].notna().sum())
gdf[[
    "score_total",
    "score_zentralitaet",
    "score_versorgung",
    "score_umwelt",
    "score_mobilitaet",
]].corr()

# %% [markdown]
# # Validierung
#
# Im Folgenden werden die Z-Variablen genutzt, um mittels K-Means-Clustering Wohnlagen zu identifizieren. Zunächst wird die optimale Clusteranzahl mittels Elbow-Methode und Silhouetten-Analyse bestimmt. Danach wird das finale K-Means-Modell mit der gewählten Clusteranzahl trainiert und die Wohnlagen den Adressen zugewiesen.

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Z-Variablen aus allen Kategorien
z_vars = [
    # Zentralität
    "z_centrality",

    # Einzelhandel
    "z_einzelhandel_distance",
    "z_einzelhandel_near_500",

    # Lärm
    "z_laerm_index_tag",

    # Haltestellen / Mobilität
    "z_haltestelle_distance",
    "z_haltestellen_count_within_500m",
    "z_haltestellen_linien_count",
    #"z_headway_score",
    #"z_rail_penalty",   # bewusst KEIN zscore, sondern Strafterm
    ]

# Validierung
missing = [c for c in z_vars if c not in gdf.columns]
if missing:
    raise ValueError(f"Diese Z-Variablen fehlen im gdf: {missing}")

# Datenmatrix: nur vollständige Zeilen
X = gdf[z_vars].dropna().values

# Elbow-Methode
inertia = []
cluster_range = range(2, 15)

for k in cluster_range:
    model = KMeans(n_clusters=k, random_state=42)
    model.fit(X)
    inertia.append(model.inertia_)

plt.figure(figsize=(8,5))
plt.plot(cluster_range, inertia, marker='o')
plt.title("Elbow-Methode: KMeans-Inertia vs. Clusteranzahl")
plt.xlabel("Anzahl Cluster (k)")
plt.ylabel("Inertia (Distanz innerhalb der Cluster)")
plt.xticks(cluster_range)
plt.grid(True)
plt.show()

# %%
from pathlib import Path
# Silhouetten-Analyse
from sklearn.metrics import silhouette_score

silhouettes = []

for k in cluster_range:
    model = KMeans(n_clusters=k, random_state=42)
    labels = model.fit_predict(X)
    score = silhouette_score(X, labels, random_state=42)
    silhouettes.append(score)

plt.figure(figsize=(8,5))
plt.plot(cluster_range, silhouettes, marker='o', color="green")
plt.title("Silhouetten-Score pro Clusteranzahl")
plt.xlabel("Anzahl Cluster (k)")
plt.ylabel("Durchschn. Silhouetten-Koeffizient")
plt.xticks(cluster_range)
plt.grid(True)

# Zielordner anlegen (falls nicht vorhanden)
out_dir = Path("plots")
out_dir.mkdir(parents=True, exist_ok=True)

# Bild speichern
plt.savefig(
    out_dir / "silhouette_scores_2026.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
CLUSTER_EXPORT_RANGE = range(3, 8)
DEFAULT_CLUSTER_COUNT = min(CLUSTER_EXPORT_RANGE)

# %%
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_samples
from umap import UMAP
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
from IPython.display import display

KMEANS_CLUSTER_COL = "cluster_kmeans_original"
KMEANS_BLOCK_CLUSTER_COL = "cluster_kmeans_block"
KMEANS_BLOCK_CHANGED_COL = "cluster_kmeans_block_changed"


def smooth_clusters_by_block(
    gdf_input,
    source_cluster_col,
    target_cluster_col,
    changed_flag_col=None,
    block_col="block",
    min_share=0.5,
):
    gdf_result = gdf_input.copy()
    valid = gdf_result[[block_col, source_cluster_col]].dropna().copy()
    if valid.empty:
        if changed_flag_col:
            gdf_result[changed_flag_col] = False
        return gdf_result, pd.DataFrame(columns=[block_col, target_cluster_col, "address_count", "cluster_count", "share"])

    counts = (
        valid.groupby([block_col, source_cluster_col], as_index=False)
        .size()
        .rename(columns={"size": "cluster_count"})
    )
    totals = valid.groupby(block_col, as_index=False).size().rename(columns={"size": "address_count"})
    majority = counts.merge(totals, on=block_col, how="left")
    majority["share"] = majority["cluster_count"] / majority["address_count"]
    majority = majority.sort_values(
        [block_col, "share", "cluster_count", source_cluster_col],
        ascending=[True, False, False, True],
    )
    majority = majority.drop_duplicates(block_col, keep="first")
    majority = majority[majority["share"] > min_share].copy()
    majority = majority.rename(columns={source_cluster_col: target_cluster_col})

    block_lookup = dict(zip(majority[block_col], majority[target_cluster_col]))
    mask = gdf_result[block_col].isin(block_lookup)
    gdf_result[target_cluster_col] = gdf_result[source_cluster_col]
    gdf_result.loc[mask, target_cluster_col] = gdf_result.loc[mask, block_col].map(block_lookup)

    if changed_flag_col:
        changed_mask = (
            gdf_result[source_cluster_col].notna()
            & gdf_result[target_cluster_col].notna()
            & (gdf_result[source_cluster_col].astype("Int64") != gdf_result[target_cluster_col].astype("Int64"))
        )
        gdf_result[changed_flag_col] = changed_mask.fillna(False)

    print(
        f"{target_cluster_col}: {len(block_lookup)} Blöcke geglaettet, "
        f"{int(mask.sum())} Adressen auf Block-Mehrheit gesetzt."
    )
    return gdf_result, majority[[block_col, target_cluster_col, "address_count", "cluster_count", "share"]]


gdf = gdf.copy()
gdf = gdf.drop(
    columns=[
        KMEANS_CLUSTER_COL,
        KMEANS_BLOCK_CLUSTER_COL,
        KMEANS_BLOCK_CHANGED_COL,
        "cluster_kmeans",
    ],
    errors="ignore",
)

mask_complete = gdf[z_vars].notna().all(axis=1)
X = gdf.loc[mask_complete, z_vars].to_numpy()
model = KMeans(n_clusters=DEFAULT_CLUSTER_COUNT, random_state=42).fit(X)

gdf.loc[mask_complete, KMEANS_CLUSTER_COL] = model.labels_
gdf[KMEANS_CLUSTER_COL] = gdf[KMEANS_CLUSTER_COL].astype("Int64")
gdf["cluster_kmeans"] = gdf[KMEANS_CLUSTER_COL]

gdf, kmeans_block_majority = smooth_clusters_by_block(
    gdf,
    source_cluster_col=KMEANS_CLUSTER_COL,
    target_cluster_col=KMEANS_BLOCK_CLUSTER_COL,
    changed_flag_col=KMEANS_BLOCK_CHANGED_COL,
)
gdf[KMEANS_BLOCK_CLUSTER_COL] = gdf[KMEANS_BLOCK_CLUSTER_COL].astype("Int64")

silhouette_per_cluster = (
    pd.DataFrame({
        "Cluster": model.labels_,
        "silhouette_score": silhouette_samples(X, model.labels_),
    })
    .groupby("Cluster", as_index=False)
    .agg(anzahl=("silhouette_score", "size"), silhouette_score=("silhouette_score", "mean"))
)
display(silhouette_per_cluster.round(3))

cluster_centers = pd.DataFrame(model.cluster_centers_, columns=z_vars)
cluster_centers.index.name = "Cluster"
print(cluster_centers.round(2))
print(f"K-Means aktuell im Notebook berechnet fuer k={DEFAULT_CLUSTER_COUNT}.")

colors = px.colors.qualitative.Dark24


def plot_cluster_projection(df_points, df_centers, x_col, y_col, z_col, title, cluster_col="cluster_kmeans"):
    fig = go.Figure()

    for cl in sorted(df_points[cluster_col].unique()):
        sub = df_points[df_points[cluster_col] == cl]
        fig.add_trace(go.Scatter3d(
            x=sub[x_col],
            y=sub[y_col],
            z=sub[z_col],
            mode="markers",
            marker=dict(
                size=3.5,
                color=colors[int(cl) % len(colors)],
                opacity=0.65
            ),
            name=f"Cluster {int(cl)}"
        ))

    fig.add_trace(go.Scatter3d(
        x=df_centers[x_col],
        y=df_centers[y_col],
        z=df_centers[z_col],
        mode="markers",
        marker=dict(
            size=6,
            color="black",
            symbol="x",
            opacity=0.9
        ),
        name="Cluster-Zentren"
    ))

    fig.update_layout(
        title=title,
        scene=dict(
            xaxis_title=x_col,
            yaxis_title=y_col,
            zaxis_title=z_col
        ),
        height=750,
        legend=dict(itemsizing="constant")
    )
    fig.show()


pca3 = PCA(n_components=3, random_state=42)
X_pca3 = pca3.fit_transform(X)
centers_pca3 = pca3.transform(cluster_centers.to_numpy())
print("Explained variance ratio (3 PCs):", pca3.explained_variance_ratio_)

df_pca = pd.DataFrame({
    "PC1": X_pca3[:, 0],
    "PC2": X_pca3[:, 1],
    "PC3": X_pca3[:, 2],
    "cluster_kmeans": model.labels_,
})

df_centers_pca = pd.DataFrame({
    "PC1": centers_pca3[:, 0],
    "PC2": centers_pca3[:, 1],
    "PC3": centers_pca3[:, 2],
    "cluster_kmeans": range(DEFAULT_CLUSTER_COUNT),
})

plot_cluster_projection(
    df_points=df_pca,
    df_centers=df_centers_pca,
    x_col="PC1",
    y_col="PC2",
    z_col="PC3",
    title=f"Hauptkomponentenprojektion (PCA) - KMeans-Cluster (k={DEFAULT_CLUSTER_COUNT})",
)

umap_neighbors = min(15, max(2, len(X) - 1))
umap3 = UMAP(
    n_components=3,
    n_neighbors=umap_neighbors,
    min_dist=0.1,
    metric="euclidean",
    transform_seed=42,
)
X_umap3 = umap3.fit_transform(X)
centers_umap3 = umap3.transform(cluster_centers.to_numpy())
print(f"UMAP embedding (3 Komponenten) mit n_neighbors={umap_neighbors}")

df_umap = pd.DataFrame({
    "UMAP1": X_umap3[:, 0],
    "UMAP2": X_umap3[:, 1],
    "UMAP3": X_umap3[:, 2],
    "cluster_kmeans": model.labels_,
})

df_centers_umap = pd.DataFrame({
    "UMAP1": centers_umap3[:, 0],
    "UMAP2": centers_umap3[:, 1],
    "UMAP3": centers_umap3[:, 2],
    "cluster_kmeans": range(DEFAULT_CLUSTER_COUNT),
})

plot_cluster_projection(
    df_points=df_umap,
    df_centers=df_centers_umap,
    x_col="UMAP1",
    y_col="UMAP2",
    z_col="UMAP3",
    title=f"UMAP-Projektion - KMeans-Cluster (k={DEFAULT_CLUSTER_COUNT})",
)

# %%
import folium

kmeans_summary = (
    gdf[[KMEANS_CLUSTER_COL, KMEANS_BLOCK_CLUSTER_COL, KMEANS_BLOCK_CHANGED_COL]]
    .dropna(subset=[KMEANS_CLUSTER_COL])
    .assign(
        **{
            KMEANS_CLUSTER_COL: lambda df: df[KMEANS_CLUSTER_COL].astype(int),
            KMEANS_BLOCK_CLUSTER_COL: lambda df: df[KMEANS_BLOCK_CLUSTER_COL].astype(int),
        }
    )
)
display(
    kmeans_summary.groupby([KMEANS_CLUSTER_COL, KMEANS_BLOCK_CLUSTER_COL], dropna=False)
    .size()
    .rename("adressen")
    .reset_index()
    .sort_values([KMEANS_CLUSTER_COL, KMEANS_BLOCK_CLUSTER_COL])
)
print(
    f"K-Means Original vs. Block-Glättung fuer k={DEFAULT_CLUSTER_COUNT}: "
    f"{int(kmeans_summary[KMEANS_BLOCK_CHANGED_COL].fillna(False).sum())} Adressen geaendert."
)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Nur Spalten verwenden, die im gdf enthalten sind
cols = [col for col in z_vars if col in gdf.columns]

# Korrelationsmatrix berechnen
corr = gdf[cols].corr()

# Plot
plt.figure(figsize=(20, 16))
sns.heatmap(corr, annot=True, cmap="vlag", center=0)
plt.title("Korrelationsmatrix der Z-Scores")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Interaktive Karte zur Bewertung einzelner Adressen

# %%
import ipywidgets as widgets
from IPython.display import display
import matplotlib.pyplot as plt
import numpy as np
import base64
from io import BytesIO

# Widget für Adresseingabe
text_input = widgets.Text(
    value='Kurstraße 15',
    placeholder='Straßenname Hausnummer',
    description='Adresse:',
    disabled=False
)

button = widgets.Button(description="Zeige Routen")
output = widgets.Output()

# Hilfsfunktion
def load_geojson(geo):
    """Konvertiert GeoJSON-Felder sicher in ein Python-Dict."""
    if geo is None:
        return None
    if isinstance(geo, float):  # NaN
        return None
    if isinstance(geo, dict):   # bereits dict
        return geo
    if isinstance(geo, str) and geo.strip() == "":
        return None
    if isinstance(geo, str):
        try:
            return json.loads(geo)
        except Exception:
            return None
    return None

def scale_score(z):
    """Skaliert Z-Score linear auf 0 - 10 für Bürgerverständlichkeit."""
    if pd.isna(z):
        return None
    score = (z + 3) / 6 * 10
    return max(0, min(10, round(score, 1)))

gdf["score_total_scaled"]        = gdf["score_total"].apply(scale_score)
gdf["score_zentralitaet_scaled"] = gdf["score_zentralitaet"].apply(scale_score)
gdf["score_versorgung_scaled"]   = gdf["score_versorgung"].apply(scale_score)
gdf["score_mobilitaet_scaled"]   = gdf["score_mobilitaet"].apply(scale_score)
gdf["score_umwelt_scaled"]       = gdf["score_umwelt"].apply(scale_score)

def score_color(value):
    if value is None:
        return "gray"
    if value >= 8:
        return "#2ecc71"   # grün
    if value >= 5:
        return "#f1c40f"   # gelb
    return "#e74c3c"        # rot

# Funktion zum Einfügen einer Route + Zielmarker
def add_route(m, geojson_raw, color, label, icon, distance=None):
    geo = load_geojson(geojson_raw)
    if not geo:
        return  # keine Route vorhanden

    if geo.get("type") == "LineString":
        try:
            coords = [(y, x) for x, y in geo["coordinates"]]
        except Exception as e:
            print(f"Fehler beim Lesen der Koordinaten für {label}: {e}")
            return

        distance_text = f" – {int(distance)} m" if distance else ""
        tooltip_text = f"{label}{distance_text}"

        folium.PolyLine(
            locations=coords,
            color=color,
            weight=4,
            opacity=0.9,
            tooltip=tooltip_text
        ).add_to(m)

        # Zielpunkt markieren
        end = coords[-1]
        folium.Marker(
            location=end,
            icon=folium.Icon(color=color, icon=icon, prefix="fa"),
            tooltip=f"Ziel: {label}{distance_text}"
        ).add_to(m)

def get_building_type(row, building_type_cols):
    """Gibt den aktiven Gebäudetyp aus One-Hot-Spalten zurück."""
    for col in building_type_cols:
        if row.get(col, 0) == 1:
            return col.replace("bt_", "").replace("_", " ")
    return "unbekannt"

# Funktion zum Anzeigen der Karte
def show_routes(_=None):
    output.clear_output(wait=True)
    with output:
        addr = text_input.value.strip().lower()

        filtered = gdf[gdf["Adresse_merge"].str.lower().str.contains(addr)].copy()
        if filtered.empty:
            print("Keine passende Adresse gefunden.")
            return

        row = filtered.iloc[0]

        m = folium.Map(
            tiles="cartodbpositron",
            location=CITY_CENTER,
            zoom_start=12,
        )

        # Farbige Score-Badges
        def badge(label, val):
            col = score_color(val)
            return f"<div style='padding:4px 8px;margin:2px;background:{col};color:white;border-radius:4px;display:inline-block;'>{label}: {val}</div>"

        popup_html = f"""
        <div style="width:420px;font-family:Arial, sans-serif;">
          <h2>{row['Straßenname']} {row['Hsnr']}</h2>

          <h3>Gesamtbewertung</h3>
          {badge("Gesamt", row.get('score_total_scaled'))}

          <h3>Teilbereiche</h3>
          {badge("Zentralität", row.get('score_zentralitaet_scaled'))}
          {badge("Versorgung", row.get('score_versorgung_scaled'))}
          {badge("Mobilität", row.get('score_mobilitaet_scaled'))}
          {badge("Umwelt", row.get('score_umwelt_scaled'))}

          <h3 style="margin-top:15px;">Wohnlagen-Typ</h3>
          <ul>
            <li><b>Baualtersklasse:</b> {row.get("building_age_class", "unbekannt")}</li>
            <li><b>Gebäudetyp:</b> {row.get("building_type")}</li>
          </ul>

          <h3 style="margin-top:15px;">Fußläufige Entfernungen</h3>
          <ul>
            <li><b>Entfernung Zentrum:</b> {int(row.get("center_distance",0))} m</li>
            <li><b>Nächste Haltestelle:</b> {row.get("haltestellen_target_name") if pd.notna(row.get("haltestellen_target_name")) else "unbekannt"} ({int(row.get("haltestellen_min_distance",0))} m)</li>
            <li><b>Nächster Einzelhandel:</b> {int(row.get("einzelhandel_min_distance",0))} m</li>
          </ul>
        </div>
        """

        popup = folium.Popup(popup_html, max_width=450)

        marker = folium.Marker(
            location=[row.lat, row.lon],
            popup=popup,
            icon=folium.Icon(color="blue", icon="info-sign")
        ).add_to(m)

        # Popup automatisch öffnen
        marker.add_child(folium.Popup(popup_html, max_width=450))
        marker.add_child(folium.map.Tooltip(""))  # kein Tooltip

        # Popup sofort anzeigen
        marker._popup = popup

        # Startmarker
        folium.Marker(
            location=[row.lat, row.lon],
            popup=popup_html,
        ).add_to(m)

        # ▸ Routen einfügen
        add_route(m, row.get("center_route"), "lightgray", "Weg zum Zentrum", "arrows-to-circle", row.get("center_distance"))
        add_route(m, row.get("haltestellen_route"), "beige", "Nächste Haltestelle", "bus", row.get("haltestellen_min_distance"))
        add_route(m, row.get("einzelhandel_route"), "purple", "Nächster Einzelhandel", "shop", row.get("einzelhandel_min_distance"))

        display(m)

# Button-Event
button.on_click(show_routes)

# UI anzeigen
display(text_input, button, output)

# %% [markdown]
# # Räumliches Clustering
# Ein Ziel der Analyse ist die Entwicklung zusammenhängender Gebiete, die einer gemeinsamen Wohnlage zugeordnet werden können. Damit sollen "Insellagen", also mehrere abgeschnittene Bereiche mit derselben Wohnlage vermieden werden. Dafür wenden wir im Folgenden eine Glättung mit dem SKATER-Ansatz an (vgl. [Assunção et al. 2006](https://doi.org/10.1080/13658810600665111])).

# %%
import os
import numpy as np
from libpysal.weights import Rook
from spopt.region import Skater

SKATER_CLUSTER_RANGE = range(3, 7)
SKATER_BLOCK_FLOOR = 8
SKATER_BLOCK_MIN_COMPONENT_SIZE = SKATER_BLOCK_FLOOR + 1

SKATER_UNCLUSTERABLE_BLOCKS_CSV = "out/skater_unclusterbare_bloecke_2026.csv"
SKATER_UNCLUSTERABLE_ADDRESSES_CSV = "out/skater_unclusterbare_adressen_2026.csv"


gdf = gdf.to_crs(epsg=32633).copy().reset_index(drop=True)
if "address_id" not in gdf.columns:
    gdf["address_id"] = gdf.index.astype(int)

missing_block_rows = int(gdf["block"].isna().sum())
if missing_block_rows > 0:
    print(f"WARNUNG: {missing_block_rows} Adressen ohne Blockzuordnung werden fuer Block-SKATER ignoriert.")


def summarize_weights(W, label):
    component_sizes = pd.Series(W.component_labels).value_counts().sort_values()
    smallest_component = int(component_sizes.iloc[0])
    largest_component = int(component_sizes.iloc[-1])
    print(
        f"{label}: n_components={W.n_components}, min_component_size={smallest_component}, "
        f"max_component_size={largest_component}, islands={len(W.islands)}"
    )
    return smallest_component


def build_block_weights(gdf_polygons, min_component_size):
    W_rook = Rook.from_dataframe(gdf_polygons)
    W_rook = W_rook.symmetrize()
    smallest_component = summarize_weights(W_rook, "Rook")
    if smallest_component >= min_component_size:
        print("Verwende Rook-Kontiguitaet fuer Block-SKATER.")
        return W_rook, "Rook"
    raise ValueError(
        f"Rook-Kontiguitaet nicht geeignet: kleinste Komponente kleiner als floor={min_component_size}."
    )


gdf_cluster_base = gdf.drop(
    columns=[KMEANS_CLUSTER_COL, KMEANS_BLOCK_CLUSTER_COL, KMEANS_BLOCK_CHANGED_COL, "cluster_kmeans"],
    errors="ignore",
).copy()
kmeans_result_cache = {}


def run_kmeans_for_n_clusters(n_clusters):
    if n_clusters in kmeans_result_cache:
        return kmeans_result_cache[n_clusters]

    gdf_result = gdf_cluster_base.copy()
    mask_complete = gdf_result[z_vars].notna().all(axis=1)
    X_local = gdf_result.loc[mask_complete, z_vars].to_numpy()
    model_local = KMeans(n_clusters=n_clusters, random_state=42).fit(X_local)
    gdf_result.loc[mask_complete, KMEANS_CLUSTER_COL] = model_local.labels_
    gdf_result[KMEANS_CLUSTER_COL] = gdf_result[KMEANS_CLUSTER_COL].astype("Int64")
    gdf_result["cluster_kmeans"] = gdf_result[KMEANS_CLUSTER_COL]
    gdf_result, kmeans_majority = smooth_clusters_by_block(
        gdf_result,
        source_cluster_col=KMEANS_CLUSTER_COL,
        target_cluster_col=KMEANS_BLOCK_CLUSTER_COL,
        changed_flag_col=KMEANS_BLOCK_CHANGED_COL,
    )
    gdf_result[KMEANS_BLOCK_CLUSTER_COL] = gdf_result[KMEANS_BLOCK_CLUSTER_COL].astype("Int64")
    result = (gdf_result, model_local, kmeans_majority)
    kmeans_result_cache[n_clusters] = result
    return result


gdf_skater_base, _, _ = run_kmeans_for_n_clusters(DEFAULT_CLUSTER_COUNT)
gdf_blockgrenzen_skater = gpd.read_file("data/2026-02-12-Blockgrenzen.gpkg")[["BLOCK", "geometry"]].rename(columns={"BLOCK": "block"})
gdf_blockgrenzen_skater = gdf_blockgrenzen_skater.to_crs(gdf.crs)
block_feature_aggs = {"address_count": ("block", "size")}
block_feature_aggs.update({col: (col, "mean") for col in z_vars})
block_features = (
    gdf_skater_base.dropna(subset=["block"])
    .groupby("block", as_index=False)
    .agg(**block_feature_aggs)
)
gdf_blocks_skater_merged = gdf_blockgrenzen_skater.merge(block_features, on="block", how="left")
block_required_cols = ["address_count"] + z_vars
mask_block_complete = gdf_blocks_skater_merged[block_required_cols].notna().all(axis=1)
dropped_block_rows = int((~mask_block_complete).sum())
if dropped_block_rows > 0:
    print(f"WARNUNG: {dropped_block_rows} Blöcke ohne vollstaendige aggregierte z-Werte vor Block-SKATER entfernt.")

gdf_blocks_unclusterable = gdf_blocks_skater_merged.loc[~mask_block_complete].copy()
if not gdf_blocks_unclusterable.empty:
    missing_matrix = gdf_blocks_unclusterable[block_required_cols].isna()
    gdf_blocks_unclusterable["skater_unclusterable_reason"] = "fehlende_aggregierte_skater_features"
    gdf_blocks_unclusterable["missing_feature_count"] = missing_matrix.sum(axis=1)
    gdf_blocks_unclusterable["missing_features"] = missing_matrix.apply(
        lambda row: ", ".join([col for col, is_missing in row.items() if is_missing]),
        axis=1,
    )

gdf_blocks_skater_base = gdf_blocks_skater_merged.loc[mask_block_complete].copy().reset_index(drop=True)


def run_block_skater_for_n_clusters(n_clusters, verbose=True):
    gdf_blocks_result = gdf_blocks_skater_base.copy()
    W_blocks, weights_label = build_block_weights(
        gdf_blocks_result,
        min_component_size=SKATER_BLOCK_MIN_COMPONENT_SIZE,
    )

    if verbose:
        print(
            "Block-SKATER:",
            "len(gdf_blocks_result)=",
            len(gdf_blocks_result),
            "W_blocks.n=",
            W_blocks.n,
            "weights=",
            weights_label,
            "clusters=",
            n_clusters,
        )

    sk_blocks = Skater(
        gdf_blocks_result,
        W_blocks,
        z_vars,
        n_clusters=n_clusters,
        islands="increase",
        floor=SKATER_BLOCK_FLOOR,
    )
    sk_blocks.solve()
    gdf_blocks_result["cluster_skater_block"] = sk_blocks.labels_.astype(int)

    gdf_result = gdf_skater_base.drop(
        columns=["cluster_skater_block", "cluster_skater"],
        errors="ignore",
    ).merge(
        gdf_blocks_result[["block", "cluster_skater_block"]],
        on="block",
        how="left",
        validate="many_to_one",
    )
    return gdf_result, gdf_blocks_result, weights_label


cluster_result_cache = {}


def compile_cluster_results(n_clusters, verbose=True):
    if n_clusters in cluster_result_cache:
        return cluster_result_cache[n_clusters]

    gdf_result, _, _ = run_kmeans_for_n_clusters(n_clusters)

    gdf_block_result, gdf_blocks_result, block_weights_label = run_block_skater_for_n_clusters(
        n_clusters,
        verbose=verbose,
    )
    gdf_result["cluster_skater_block"] = gdf_block_result["cluster_skater_block"].astype("Int64")

    gdf_result["cluster_skater_block_changed_vs_kmeans"] = (
        gdf_result["cluster_skater_block"].notna()
        & gdf_result[KMEANS_CLUSTER_COL].notna()
        & (gdf_result["cluster_skater_block"] != gdf_result[KMEANS_CLUSTER_COL])
    ).fillna(False)
    gdf_result["cluster_skater"] = gdf_result["cluster_skater_block"]

    meta = {
        "n_clusters": n_clusters,
        "block_weights_label": block_weights_label,
    }
    result = (gdf_result, gdf_blocks_result, meta)
    cluster_result_cache[n_clusters] = result
    return result


gdf, gdf_blocks_skater, skater_meta = compile_cluster_results(DEFAULT_CLUSTER_COUNT)
skater_weights_label = skater_meta["block_weights_label"]

os.makedirs("out", exist_ok=True)

block_export_cols = [
    "block",
    "address_count",
    "skater_unclusterable_reason",
    "missing_feature_count",
    "missing_features",
    "geometry",
]
if gdf_blocks_unclusterable.empty:
    empty_block_export = pd.DataFrame(columns=block_export_cols)
    empty_block_export.to_csv(SKATER_UNCLUSTERABLE_BLOCKS_CSV, index=False, encoding="utf-8")
    print(f"CSV exportiert (leer): {SKATER_UNCLUSTERABLE_BLOCKS_CSV}")
else:
    gdf_blocks_unclusterable_export = gdf_blocks_unclusterable.copy()
    gdf_blocks_unclusterable_export["geometry"] = gdf_blocks_unclusterable_export.geometry.apply(
        lambda geom: geom.wkt if geom is not None else None
    )
    gdf_blocks_unclusterable_export = gdf_blocks_unclusterable_export[block_export_cols]
    gdf_blocks_unclusterable_export.to_csv(SKATER_UNCLUSTERABLE_BLOCKS_CSV, index=False, encoding="utf-8")
    print(f"CSV exportiert: {SKATER_UNCLUSTERABLE_BLOCKS_CSV} ({len(gdf_blocks_unclusterable_export)} Blöcke)")

unclusterable_block_ids = set(gdf_blocks_unclusterable["block"].dropna().astype(str))
gdf_unclusterable_addresses = gdf[gdf["cluster_skater_block"].isna()].copy()
if not gdf_unclusterable_addresses.empty:
    gdf_unclusterable_addresses["skater_unclusterable_reason"] = np.where(
        gdf_unclusterable_addresses["block"].isna(),
        "keine_blockzuordnung",
        np.where(
            gdf_unclusterable_addresses["block"].astype(str).isin(unclusterable_block_ids),
            "block_unclusterbar",
            "nicht_von_skater_zugeordnet",
        ),
    )

address_export_cols = [
    "address_id",
    "Straßenname",
    "Hsnr",
    "HsnrZus",
    "Adresse_merge",
    "block",
    "cluster_kmeans",
    "cluster_skater_block",
    "skater_unclusterable_reason",
    "lat",
    "lon",
    "geometry",
]
available_address_cols = [col for col in address_export_cols if col in gdf_unclusterable_addresses.columns]
if "geometry" in available_address_cols:
    gdf_unclusterable_addresses["geometry"] = gdf_unclusterable_addresses.geometry.apply(
        lambda geom: geom.wkt if geom is not None else None
    )

if gdf_unclusterable_addresses.empty:
    pd.DataFrame(columns=[col for col in address_export_cols if col != "geometry"] + ["geometry"]).to_csv(
        SKATER_UNCLUSTERABLE_ADDRESSES_CSV,
        index=False,
        encoding="utf-8",
    )
    print(f"CSV exportiert (leer): {SKATER_UNCLUSTERABLE_ADDRESSES_CSV}")
else:
    gdf_unclusterable_addresses[available_address_cols].to_csv(
        SKATER_UNCLUSTERABLE_ADDRESSES_CSV,
        index=False,
        encoding="utf-8",
    )
    print(f"CSV exportiert: {SKATER_UNCLUSTERABLE_ADDRESSES_CSV} ({len(gdf_unclusterable_addresses)} Adressen)")

print(
    f"SKATER aktuell im Notebook berechnet fuer k={DEFAULT_CLUSTER_COUNT}. "
    f"Block-Gewichte={skater_meta['block_weights_label']}."
)
print(
    gdf[
        [
            "block",
            KMEANS_CLUSTER_COL,
            KMEANS_BLOCK_CLUSTER_COL,
            "cluster_skater_block",
        ]
    ].dropna(how="all").head()
)

# %% [markdown]
# ## Zusätzliche Plausibilisierung der räumlichen Lösung
#
# Die SKATER-Lösung wird hier aus drei Perspektiven geprüft:
#
# - **Modellgüte über wenige fachlich plausible Clusterzahlen:** Die Kennzahlen werden direkt für SKATER auf Blockebene nur für `k=3` bis `k=7` berechnet.
# - **Stabile Clustergrößen:** Mit `floor=8` werden sehr kleine Cluster vermieden; zusätzlich wird die Größenverteilung über diesen kleinen Suchraum sichtbar gemacht.
# - **Externe Plausibilität:** Die resultierenden Cluster sollten mit der Mietkategorie zusammenhängen, wenn sie reale Lageunterschiede abbilden.
#
# Für eine Mittelstadt dieser Größenordnung ist dabei nicht die maximal mögliche Differenzierung das Ziel. Bevorzugt werden vielmehr wenige, verständlich kommunizierbare Wohnlagencluster, sofern deren Modellgüte und externe Plausibilität tragfähig bleiben.

# %% [markdown]
# ### Wie die Kennzahlen zu lesen sind
#
# - **Silhouette:** höher ist besser. Werte nahe `1` bedeuten gut getrennte Cluster; Werte um `0` deuten auf Überlappung hin.
# - **Clustergrößen:** Für die Praxis sind nicht nur gute Kennzahlen wichtig, sondern auch ausreichend große, erklärbare Cluster. Sehr kleine Cluster wären für Wohnlagen meist schwer vermittelbar.
# - **Cramérs V:** misst den Zusammenhang zwischen SKATER-Clustern und Mietkategorien. Werte nahe `0` bedeuten kaum Zusammenhang, höhere Werte sprechen für externe Plausibilität.
# - **Eta²:** zeigt, wie stark sich `score_total` zwischen den Clustern unterscheidet. Höhere Werte bedeuten stärkere Trennung zwischen den Wohnlagen.
#
# Entscheidend ist nicht das Extrem eines einzelnen Kennwerts, sondern eine insgesamt robuste Lösung: gute Trennung, keine unplausibel kleinen Cluster und eine nachvollziehbare Verbindung zu externen Lageindikatoren.

# %%
from pathlib import Path
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
from sklearn.metrics import silhouette_score
from scipy.stats import chi2_contingency, kruskal


def cramers_v_corrected(contingency_table):
    chi2, p_value, dof, _ = chi2_contingency(contingency_table)
    n = contingency_table.to_numpy().sum()
    if n <= 1:
        return chi2, p_value, dof, np.nan

    phi2 = chi2 / n
    r, k = contingency_table.shape
    phi2corr = max(0, phi2 - ((k - 1) * (r - 1)) / (n - 1))
    rcorr = r - ((r - 1) ** 2) / (n - 1)
    kcorr = k - ((k - 1) ** 2) / (n - 1)
    denom = min(kcorr - 1, rcorr - 1)
    cramers_v = np.sqrt(phi2corr / denom) if denom > 0 else np.nan
    return chi2, p_value, dof, cramers_v


def ensure_spatial_context_columns(gdf_input):
    required = {"quartier", "ortsteil", "mietkategorie"}
    if required.issubset(gdf_input.columns):
        return gdf_input

    original_crs = gdf_input.crs
    gdf_local = gdf_input.to_crs(4326).copy()
    gdf_local = gdf_local.drop(columns=["index_right", "quartier", "ortsteil", "mietkategorie", "bezeichnun", "mietkatego", "otl_name"], errors="ignore")
    cols_to_drop = [col for col in gdf_local.columns if col.endswith("_quartier")]
    gdf_local = gdf_local.drop(columns=cols_to_drop, errors="ignore")

    gdf_quartiere_val = gpd.read_file("data/Quartiere/2024_Quartiere.gpkg").to_crs(4326)
    gdf_ortsteile_val = gpd.read_file("data/ortsteile_brandenburg.json", bbox=CITY_BOUNDING_BOX).to_crs(4326)
    gdf_ortsteile_val = gdf_ortsteile_val.drop(columns=["otl_aktualitaet"], errors="ignore")

    gdf_local = gpd.sjoin(
        gdf_local,
        gdf_quartiere_val[["bezeichnun", "mietkatego", "geometry"]],
        how="left",
        predicate="within",
    )
    gdf_local = gdf_local.drop(columns=["index_right"], errors="ignore")

    gdf_local = gpd.sjoin(
        gdf_local,
        gdf_ortsteile_val[["otl_name", "geometry"]],
        how="left",
        predicate="within",
    )
    gdf_local = gdf_local.drop(columns=["index_right"], errors="ignore")
    gdf_local = gdf_local.rename(columns={
        "bezeichnun": "quartier",
        "mietkatego": "mietkategorie",
        "otl_name": "ortsteil",
    })
    return gdf_local.to_crs(original_crs)


gdf = ensure_spatial_context_columns(gdf)

skater_cluster_range = CLUSTER_EXPORT_RANGE
skater_eval_rows = []

for k in skater_cluster_range:
    _, gdf_blocks_eval, _ = run_block_skater_for_n_clusters(k, verbose=False)
    X_blocks = gdf_blocks_eval[z_vars].to_numpy()
    labels = gdf_blocks_eval["cluster_skater_block"].to_numpy()
    cluster_sizes = gdf_blocks_eval.groupby("cluster_skater_block")["address_count"].sum()

    skater_eval_rows.append({
        "k": k,
        "silhouette": silhouette_score(X_blocks, labels),
        "smallest_cluster_addresses": int(cluster_sizes.min()),
        "largest_cluster_addresses": int(cluster_sizes.max()),
        "size_ratio": float(cluster_sizes.max() / cluster_sizes.min()),
    })

skater_eval_df = pd.DataFrame(skater_eval_rows)
out_dir = Path("plots")
out_dir.mkdir(parents=True, exist_ok=True)
skater_eval_df.to_csv(out_dir / "skater_model_selection_metrics_2026.csv", index=False, encoding="utf-8")

display(skater_eval_df.round(3))

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
axes[0].plot(skater_eval_df["k"], skater_eval_df["silhouette"], marker="o", color="steelblue", label="Silhouette")
axes[0].axvline(DEFAULT_CLUSTER_COUNT, color="black", linestyle="--", linewidth=1, label=f"gewähltes k={DEFAULT_CLUSTER_COUNT}")
axes[0].set_title("SKATER-Silhouette nach Clusterzahl")
axes[0].set_xlabel("Anzahl Cluster (k)")
axes[0].set_ylabel("Silhouette")
axes[0].set_xticks(list(skater_cluster_range))
axes[0].grid(True, alpha=0.3)
axes[0].legend()

axes[1].plot(skater_eval_df["k"], skater_eval_df["smallest_cluster_addresses"], marker="o", color="steelblue", label="kleinstes Cluster")
axes[1].plot(skater_eval_df["k"], skater_eval_df["largest_cluster_addresses"], marker="o", color="darkorange", label="größtes Cluster")
axes[1].set_title("SKATER-Cluster (Block)größen nach Clusterzahl")
axes[1].set_xlabel("Anzahl Cluster (k)")
axes[1].set_ylabel("Anzahl Adressen")
axes[1].set_xticks(list(skater_cluster_range))
axes[1].grid(True, alpha=0.3)
axes[1].legend()

plt.tight_layout()
plt.savefig(out_dir / "skater_model_selection_overview_2026.png", dpi=300, bbox_inches="tight")
plt.show()

miet_valid = gdf.dropna(subset=["mietkategorie", "cluster_skater_block"]).copy()
if miet_valid.empty:
    raise ValueError(
        "Die Spalte 'mietkategorie' wurde zwar ergänzt, enthält aber keine gültigen Werte. "
        "Bitte prüfen, ob die Quartier-Geometrien die Adressen tatsächlich räumlich schneiden."
    )
ct_miet = pd.crosstab(miet_valid["mietkategorie"], miet_valid["cluster_skater_block"])
chi2_miet, p_miet, dof_miet, cramers_v_miet = cramers_v_corrected(ct_miet)

score_valid = gdf.dropna(subset=["cluster_skater_block", "score_total"]).copy()
score_groups = [grp["score_total"].values for _, grp in score_valid.groupby("cluster_skater_block") if len(grp) > 0]
kw_stat, kw_p = kruskal(*score_groups)
overall_mean = score_valid["score_total"].mean()
cluster_means = score_valid.groupby("cluster_skater_block")["score_total"].mean()
cluster_sizes = score_valid.groupby("cluster_skater_block").size()
ss_total = ((score_valid["score_total"] - overall_mean) ** 2).sum()
ss_between = (((cluster_means - overall_mean) ** 2) * cluster_sizes).sum()
eta_sq = ss_between / ss_total if ss_total else np.nan

validation_summary = pd.DataFrame([
    {
        "Kriterium": "Zusammenhang SKATER vs. Mietkategorie (Cramérs V)",
        "Wert": cramers_v_miet,
    },
    {
        "Kriterium": "p-Wert Mietkategorie vs. SKATER (Chi-Quadrat)",
        "Wert": p_miet,
    },
    {
        "Kriterium": "Zwischen-Cluster-Streuung im score_total (Eta²)",
        "Wert": eta_sq,
    },
    {
        "Kriterium": "p-Wert score_total nach SKATER-Cluster (Block)n (Kruskal-Wallis)",
        "Wert": kw_p,
    },
])

display(validation_summary.round(4))
validation_summary.to_csv(out_dir / "skater_validation_summary_2026.csv", index=False, encoding="utf-8")

plot_ct = pd.crosstab(miet_valid["mietkategorie"], miet_valid["cluster_skater_block"], normalize="columns")
plt.figure(figsize=(8, 4.5))
sns.heatmap(plot_ct, cmap="Blues", annot=True, fmt=".2f")
plt.title("Mietkategorie je SKATER-Cluster (Block) (Spalten-normalisiert)")
plt.xlabel("SKATER-Cluster (Block)")
plt.ylabel("Mietkategorie")
plt.tight_layout()
plt.savefig(out_dir / "skater_mietkategorie_validation_2026.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# # Cluster-Karte

# %%
MAP_EXPORT_TEMPLATE = 'maps/brb_{n_clusters}_clusters_26.html'

import folium
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.colors as mcolors
from branca.element import Element

gdf_quartiere = gpd.read_file("data/Quartiere/2024_Quartiere.gpkg").to_crs(4326)
gdf_ortsteile = gpd.read_file("data/ortsteile_brandenburg.json", bbox=CITY_BOUNDING_BOX).to_crs(4326)
gdf_ortsteile.drop(columns=["otl_aktualitaet"], inplace=True, errors="ignore")
gdf_blockgrenzen_map = gpd.read_file("data/2026-02-12-Blockgrenzen.gpkg")[["BLOCK", "geometry"]].rename(columns={"BLOCK": "block"}).to_crs(4326)


KMEANS_PALETTE = [
    "#0B3C5D",  # deep navy
    "#0077B6",  # saturated blue
    "#2A9D8F",  # teal
    "#6C8EAD",  # slate blue
    "#00A6D6",  # cyan-blue
    "#4B5D9A",  # indigo blue
    "#66C2D7",  # light aqua
]
SKATER_PALETTE = [
    "#A61C00",  # strong red
    "#E6550D",  # vivid orange
    "#8C510A",  # brown-ochre
    "#C75146",  # brick red
    "#F28E2B",  # amber
    "#6F3B08",  # dark brown
    "#D17C00",  # ochre
]
FREISTEHENDE_BUILDING_TYPES = {
    "Freistehendes EFH",
    "Freistehendes ZWH",
    "Freistehendes ZFH",
}
FREISTEHEND_HIGHLIGHT_COLOR = "#ffffce"


def get_cluster_colors(n_clusters, palette):
    return {i: palette[i % len(palette)] for i in range(n_clusters)}


def adjust_hex(hex_color, factor=1.0):
    rgb = np.array(mcolors.to_rgb(hex_color))
    if factor >= 1:
        adjusted = 1 - (1 - rgb) / factor
    else:
        adjusted = rgb * factor
    return mcolors.to_hex(np.clip(adjusted, 0, 1))


def get_cluster_colors_from_series(series, palette):
    valid = pd.Series(series).dropna().astype(int)
    if valid.empty:
        return {}
    colors = get_cluster_colors(max(valid.max() + 1, DEFAULT_CLUSTER_COUNT), palette=palette)
    return {cluster_id: colors[cluster_id] for cluster_id in sorted(valid.unique())}


def enrich_cluster_map_addresses(gdf_map):
    gdf_local = gdf_map.to_crs(4326).copy()
    gdf_local = gdf_local.drop(
        columns=["index_right", "mietkatego", "mietkategorie", "bezeichnun", "quartier", "ortsteil"],
        errors="ignore",
    )
    cols_to_drop = [col for col in gdf_local.columns if col.endswith("_quartier")]
    gdf_local = gdf_local.drop(columns=cols_to_drop, errors="ignore")
    gdf_local = gpd.sjoin(
        gdf_local,
        gdf_quartiere[["bezeichnun", "mietkatego", "geometry"]],
        how="left",
        predicate="within",
    )
    gdf_local = gdf_local.drop(columns=["index_right", "otl_name", "index_left", "otl_name_left", "otl_name_right"], errors="ignore")
    gdf_local = gpd.sjoin(
        gdf_local,
        gdf_ortsteile[["otl_name", "geometry"]],
        how="left",
        predicate="within",
    )
    gdf_local = gdf_local.drop(columns=["index_right"], errors="ignore")
    gdf_local = gdf_local.rename(columns={
        "otl_name": "ortsteil",
        "bezeichnun": "quartier",
        "mietkatego": "mietkategorie",
    })
    return gdf_local


def format_metric(value, digits=1, suffix=""):
    if pd.isna(value):
        return "unbekannt"
    try:
        return f"{float(value):.{digits}f}{suffix}"
    except Exception:
        return str(value)


def build_address_tooltip(row, cluster_col, cluster_label, changed_label=None):
    changed_html = ""
    if changed_label:
        changed_html = f"<div><b>Hinweis:</b> {changed_label}</div>"
    freistehend_html = ""
    if bool(row.get("is_freistehend_building", False)):
        freistehend_html = "<div><b>Typologie:</b> freistehendes Gebaeude</div>"
    building_type = s(row.get("building_type")) or "unbekannt"
    return folium.Tooltip(
        f"""
        <div style="min-width:360px; max-width:520px; font-size:12px;">
          <div><b>{row.get('Straßenname', '')} {row.get('Hsnr', '')}</b></div>
          <div><b>{cluster_label}:</b> {format_metric(row.get(cluster_col), 0)}</div>
          {changed_html}
          {freistehend_html}
          <div><b>Gebäudetyp:</b> {building_type}</div>
          <div><b>Quartier:</b> {row.get('quartier', 'unbekannt')} | <b>Mietkategorie:</b> {row.get('mietkategorie', 'unbekannt')}</div>
          <div><b>Ortsteil:</b> {row.get('ortsteil', 'unbekannt')}</div>
          <div><b>score_total:</b> {format_metric(row.get('score_total'), 3)} | <b>Punkte gesamt:</b> {format_metric(row.get('score_total_scaled'))}</div>
          <div><b>Zentralität:</b> {format_metric(row.get('score_zentralitaet'), 3)} / {format_metric(row.get('score_zentralitaet_scaled'))}</div>
          <div><b>Versorgung:</b> {format_metric(row.get('score_versorgung'), 3)} / {format_metric(row.get('score_versorgung_scaled'))}</div>
          <div><b>Mobilität:</b> {format_metric(row.get('score_mobilitaet'), 3)} / {format_metric(row.get('score_mobilitaet_scaled'))}</div>
          <div><b>Lärm-Malus:</b> {format_metric(row.get('z_noise_penalty'), 3)} | <b>Lärmindex:</b> {format_metric(row.get('laerm_index_tag'), 1)}</div>
          <div><b>Zentrum:</b> {format_metric(row.get('center_distance'), 0, ' m')}</div>
          <div><b>Einzelhandel:</b> {format_metric(row.get('einzelhandel_min_distance'), 0, ' m')} | <b>Märkte in 500 m:</b> {format_metric(row.get('einzelhandel_500m_count'), 0)}</div>
          <div><b>Haltestelle:</b> {(row.get('haltestellen_target_name') if pd.notna(row.get('haltestellen_target_name')) else 'unbekannt')} ({format_metric(row.get('haltestellen_min_distance'), 0, ' m')}) | <b>Haltestellen in 500 m:</b> {format_metric(row.get('haltestellen_count_within_500m'), 0)}</div>
          <div><b>ÖPNV-Linien:</b> {format_metric(row.get('haltestellen_linien_count'), 0)}</div>
        </div>
        """,
        sticky=True,
    )


def build_block_layer_data(gdf_map, cluster_col):
    block_stats = (
        gdf_map.dropna(subset=["block", cluster_col])
        .assign(**{cluster_col: lambda df: df[cluster_col].astype(int)})
        .groupby("block", as_index=False)
        .agg(
            address_count=("address_id", "count"),
            cluster_value=(cluster_col, "first"),
        )
        .rename(columns={"cluster_value": cluster_col})
    )
    if block_stats.empty:
        return gdf_blockgrenzen_map.iloc[0:0].copy()
    return gdf_blockgrenzen_map.merge(block_stats, on="block", how="inner")


def add_quartier_layers(m):
    folium.GeoJson(
        gdf_ortsteile,
        name="Ortsteile",
        show=False,
        style_function=lambda feature: {
            "fillColor": "#D9DEE2",
            "color": "#6B7785",
            "weight": 1.2,
            "fillOpacity": 0.04,
        },
        tooltip=folium.GeoJsonTooltip(
            fields=["otl_name"],
            aliases=["Ortsteil"],
            localize=True,
            sticky=True,
        ),
    ).add_to(m)
    folium.GeoJson(
        gdf_quartiere,
        name="Quartiere = Mietkategorien",
        show=True,
        style_function=lambda feature: {
            "fillColor": "#EFE7DC",
            "color": "#8D7B68",
            "weight": 1.6,
            "fillOpacity": 0.08,
        },
        tooltip=folium.GeoJsonTooltip(
            fields=["bezeichnun", "mietkatego"],
            aliases=["Quartier", "Mietkategorie"],
            localize=True,
            sticky=True,
        ),
    ).add_to(m)


def add_address_cluster_layer(m, gdf_local, cluster_col, layer_name, colors, changed_col=None, changed_text=None, show=False):
    layer = folium.FeatureGroup(name=layer_name, show=show)
    points = gdf_local[gdf_local["lat"].notna() & gdf_local["lon"].notna() & gdf_local[cluster_col].notna()].copy()
    if points.empty:
        layer.add_to(m)
        return layer

    points[cluster_col] = points[cluster_col].astype(int)
    if changed_col and changed_col in points.columns:
        points[changed_col] = points[changed_col].fillna(False)
    if "is_freistehend_building" in points.columns:
        points["is_freistehend_building"] = points["is_freistehend_building"].fillna(False)

    for _, row in points.iterrows():
        base = colors.get(int(row[cluster_col]), "#666666")
        is_changed = changed_col and bool(row.get(changed_col, False))
        is_freistehend = bool(row.get("is_freistehend_building", False))
        marker_color = adjust_hex(base, 0.72) if is_changed else base
        marker_radius = 3.4 if is_changed else 3
        if is_freistehend:
            marker_color = FREISTEHEND_HIGHLIGHT_COLOR
            marker_radius = max(marker_radius, 3.8)
        tooltip = build_address_tooltip(
            row,
            cluster_col=cluster_col,
            cluster_label="Clusternummer",
            changed_label=changed_text if is_changed else None,
        )
        folium.CircleMarker(
            location=[row.lat, row.lon],
            radius=marker_radius,
            color=marker_color,
            fill=True,
            fill_color=marker_color,
            fill_opacity=0.95,
            weight=1,
            tooltip=tooltip,
        ).add_to(layer)

    layer.add_to(m)
    return layer


def add_block_polygon_layer(m, gdf_blocks_local, cluster_col, layer_name, colors, show=False):
    if gdf_blocks_local.empty:
        return None
    gdf_blocks_local = gdf_blocks_local.copy()
    gdf_blocks_local[cluster_col] = gdf_blocks_local[cluster_col].astype(int)
    folium.GeoJson(
        gdf_blocks_local,
        name=layer_name,
        show=show,
        style_function=lambda feature: {
            "fillColor": colors.get(feature["properties"][cluster_col], "#999999"),
            "color": adjust_hex(colors.get(feature["properties"][cluster_col], "#666666"), 0.55),
            "weight": 1.8,
            "fillOpacity": 0.28,
        },
        tooltip=folium.GeoJsonTooltip(
            fields=["block", "address_count", cluster_col],
            aliases=["Block", "Adressen", "Cluster"],
            localize=True,
            sticky=True,
        ),
    ).add_to(m)
    return m


def add_marker_legend(m):
    legend_html = """
    <div style="
        position: fixed;
        bottom: 40px;
        left: 40px;
        z-index: 9999;
        background: white;
        padding: 10px 12px;
        border: 1px solid #999;
        border-radius: 6px;
        font-size: 12px;
        line-height: 1.4;
    ">
        <div><b>Adressmarkierung</b></div>
        <div>Normale Adresse: Clusterfarbe</div>
        <div>Dunklerer Punkt: Zwangs-/Blockzuordnung</div>
        <div>Hellgelb: Freistehendes EFH oder Freistehendes ZWH</div>
    </div>
    """
    m.get_root().html.add_child(Element(legend_html))


def build_cluster_comparison_map(gdf_map, gdf_blocks_map, meta):
    gdf_local = enrich_cluster_map_addresses(gdf_map)
    m = folium.Map(location=CITY_CENTER, zoom_start=13, tiles="cartodbpositron")
    add_quartier_layers(m)

    kmeans_colors = get_cluster_colors_from_series(gdf_local[KMEANS_CLUSTER_COL], KMEANS_PALETTE)
    skater_block_colors = get_cluster_colors_from_series(gdf_local["cluster_skater_block"], SKATER_PALETTE)
    block_kmeans_regions = build_block_layer_data(gdf_local, KMEANS_BLOCK_CLUSTER_COL)
    block_skater_regions = gdf_blocks_map.to_crs(4326).copy()

    add_address_cluster_layer(
        m,
        gdf_local,
        cluster_col=KMEANS_CLUSTER_COL,
        layer_name=f"KMeans Original (Adressen, k={meta['n_clusters']})",
        colors=kmeans_colors,
        show=True,
    )
    add_block_polygon_layer(
        m,
        block_kmeans_regions,
        cluster_col=KMEANS_BLOCK_CLUSTER_COL,
        layer_name=f"KMeans Blockflaechen (k={meta['n_clusters']})",
        colors=kmeans_colors,
        show=False,
    )
    add_address_cluster_layer(
        m,
        gdf_local,
        cluster_col=KMEANS_BLOCK_CLUSTER_COL,
        layer_name=f"KMeans Block-Glättung (Adressen, k={meta['n_clusters']})",
        colors=kmeans_colors,
        changed_col=KMEANS_BLOCK_CHANGED_COL,
        changed_text="Adresse wurde gegenüber K-Means Original auf die Block-Mehrheit gesetzt.",
        show=False,
    )
    add_block_polygon_layer(
        m,
        block_skater_regions,
        cluster_col="cluster_skater_block",
        layer_name=f"SKATER Blöcke (Flächen, k={meta['n_clusters']}, {meta['block_weights_label']})",
        colors=skater_block_colors,
        show=False,
    )
    add_address_cluster_layer(
        m,
        gdf_local,
        cluster_col="cluster_skater_block",
        layer_name=f"SKATER Blöcke (Adressen, k={meta['n_clusters']})",
        colors=skater_block_colors,
        changed_col="cluster_skater_block_changed_vs_kmeans",
        changed_text="Adresse wurde gegenüber K-Means Original auf das Block-SKATER-Cluster (Block) gesetzt.",
        show=False,
    )

    add_marker_legend(m)
    folium.LayerControl(collapsed=False).add_to(m)
    return m, block_kmeans_regions, block_skater_regions


gdf_blocks_kmeans_map = None
gdf_blocks_skater_map = None
cluster_map_outputs = []
for n_clusters in CLUSTER_EXPORT_RANGE:
    gdf_map, gdf_blocks_map, meta = compile_cluster_results(n_clusters, verbose=False)
    m_cluster, gdf_blocks_kmeans_export, gdf_blocks_skater_export = build_cluster_comparison_map(gdf_map, gdf_blocks_map, meta)
    html_path = MAP_EXPORT_TEMPLATE.format(n_clusters=n_clusters)
    m_cluster.save(html_path)
    if n_clusters == DEFAULT_CLUSTER_COUNT:
        gdf_blocks_kmeans_map = gdf_blocks_kmeans_export
        gdf_blocks_skater_map = gdf_blocks_skater_export
    cluster_map_outputs.append((n_clusters, meta["block_weights_label"], html_path))

for n_clusters, block_weights_label, html_path in cluster_map_outputs:
    print(
        f"Karte erzeugt: k={n_clusters}, Block-SKATER={block_weights_label}, file={html_path}"
    )

print("Keine interaktive Karte mehr im Notebook; Karten werden nur nach maps/ exportiert.")

# %%
# Histogramm mit Anzahl der Adressen pro Cluster
import matplotlib.pyplot as plt
cluster_counts = gdf["cluster_skater_block"].value_counts().sort_index()
plt.figure(figsize=(10,6))
plt.bar(cluster_counts.index.astype(str), cluster_counts.values, color='steelblue')
plt.xlabel('Cluster')
plt.ylabel('Anzahl Adressen')
plt.title('Anzahl der Adressen pro Cluster (SKATER auf Blöcken)')
plt.xticks(cluster_counts.index.astype(str))
plt.grid(axis='y')
plt.show()

# %% [markdown]
# # Abgleich mit Ortsteilen, Quartieren und Mietkategorien
# Zum Abgleich der ermittelten Wohnlagen mit bestehenden Strukturen werden die Cluster mit den Quartieren und Ortsteilen der Adressen sowie den Mietkategorien verglichen. In der Kreuztabelle können die Verteilungen der Cluster über die verschiedenen räumlichen Einheiten analysiert werden.

# %%
# Kreuztabelle zu Quartieren
quartier_plot = gdf[["quartier", "cluster_skater_block"]].dropna().copy()
if quartier_plot.empty:
    raise ValueError(
        "Keine gueltigen Werte fuer 'quartier' und 'cluster_skater'. "
        "Pruefe den Spatial Join der Quartiere oder die vorherigen Filter auf gdf."
    )
ct = pd.crosstab(quartier_plot["quartier"], quartier_plot["cluster_skater_block"], normalize="index")
if ct.empty or ct.shape[0] == 0 or ct.shape[1] == 0:
    raise ValueError(
        f"Leere Kreuztabelle fuer Quartiere erzeugt: {ct.shape}. "
        "Pruefe, ob nach dropna()/Filterung noch Daten vorhanden sind."
    )
plt.figure(figsize=(14,10))
sns.heatmap(ct, cmap="viridis", annot=False)
plt.title("Quartier vs. SKATER-Cluster (Block) (Zeilen normalize: Anteil pro Quartier)")
plt.xlabel("SKATER-Cluster (Block)")
plt.ylabel("Quartier")
plt.tight_layout()
plt.show()

# %% [markdown]
# Die Darstellung zeigt, wie sich die automatisch gebildeten SKATER-Cluster auf die bestehenden Wohnquartiere verteilen. Deutlich wird, dass mehrere Quartiere eine klare Dominanz einzelner Cluster aufweisen (z. B. Zentrum, Nord, Görden oder Hohenstücken), was auf eine vergleichsweise homogene interne Struktur schließen lässt. Andere Quartiere, insbesondere jene mit gemischten Nutzungen oder großen räumlichen Ausdehnungen, verteilen sich stärker auf mehrere Cluster. Diese Heterogenität ist erwartbar und spiegelt eher die interne Vielfalt der Quartiere wider als Schwächen im Clustering. Insgesamt zeigt die Heatmap, dass die Clusterbildung bestehende räumliche Zusammenhänge gut trifft.

# %%
# Kreuztabelle zu Ortsteilen
ct = pd.crosstab(gdf["ortsteil"], gdf["cluster_skater_block"], normalize="index")

plt.figure(figsize=(12,8))
sns.heatmap(ct, cmap="magma", annot=False)
plt.title("Ortsteil vs. SKATER-Cluster (Block)")
plt.xlabel("SKATER-Cluster (Block)")
plt.ylabel("Ortsteil")
plt.tight_layout()
plt.show()

# %% [markdown]
# Die Zuordnung der SKATER-Cluster zu den Ortsteilen zeigt überwiegend klare Muster. Viele Ortsteile werden überwiegend einem oder zwei Clustern zugeordnet, was auf eine konsistente und funktional nachvollziehbare Lagecharakteristik schließen lässt. Dies ist besonders bei peripheren oder dörflichen Ortsteilen sichtbar, die sich typischerweise durch ähnliche Infrastrukturausstattung und Distanzlagen auszeichnen. Gleichzeitig treten - abhängig von Größe und Struktur des Ortsteils – einzelne Streuungen auf, die auf interne Unterschiede oder Übergangsbereiche hindeuten können. Insgesamt bestätigt die Darstellung, dass die Cluster auch außerhalb des Kernstadtgebiets sinnvolle, zusammenhängende Lagemuster abbilden.

# %%
ct = pd.crosstab(gdf["mietkategorie"], gdf["cluster_skater_block"], normalize="columns")

plt.figure(figsize=(10,6))
sns.heatmap(ct, cmap="coolwarm", annot=True, fmt=".2f")
plt.title("Mietkategorie vs. SKATER-Cluster (Block) (Spalten normalize)")
plt.xlabel("SKATER-Cluster (Block)")
plt.ylabel("Mietkategorie")
plt.tight_layout()
plt.show()

# %% [markdown]
# Die Kreuztabelle zwischen Mietkategorien und SKATER-Clustern dient der ökonomischen Validierung des Modells. Hier zeigt sich, dass bestimmte Cluster deutlich mit niedrigeren, mittleren oder höheren Mietkategorien assoziiert sind. Mehrere Cluster weisen eine hohe Übereinstimmung mit spezifischen Mietniveaus auf, was darauf hinweist, dass die algorithmisch erkannten Lagegruppen auch sozioökonomische Unterschiede in der Wohnlagequalität widerspiegeln. Streuungen in einzelnen Kategorien sind zu erwarten und spiegeln natürliche Übergänge oder heterogene Straßenzüge wider. Insgesamt deutet die Struktur jedoch auf eine plausibel differenzierende Wirkung der Cluster hin.

# %%
# Alle relevanten Z-Variablen für die Clusterinterpretation
z_vars = [col for col in gdf.columns if col.startswith("z_")]

cluster_profile = gdf.groupby("cluster_skater_block")[z_vars].mean()

plt.figure(figsize=(18,10))
sns.heatmap(cluster_profile, cmap="coolwarm", center=0, annot=False)
plt.title("Feature-Profil der SKATER-Cluster (Block) (Block-SKATER)")
plt.xlabel("Feature")
plt.ylabel("Cluster")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Export-Pipeline

# %%
# Save GeoDataFrame with scores and clusters as CSV
import os

EXPORT_PATH = "out"
EXPORT_GPKG = os.path.join(EXPORT_PATH, "wohnlagen_brb_2026.gpkg")
EXPORT_CSV = os.path.join(EXPORT_PATH, "wohnlagen_brb_2026.csv")

os.makedirs(EXPORT_PATH, exist_ok=True)

if os.path.exists(EXPORT_GPKG):
    os.remove(EXPORT_GPKG)
    print(f"Alte Datei geloescht: {EXPORT_GPKG}")


def write_layer(gdf_layer, layer_name, crs=EPSG_4326):
    if gdf_layer is None or len(gdf_layer) == 0:
        print(f"Layer '{layer_name}' uebersprungen: leer oder None")
        return

    if gdf_layer.crs is None:
        print(f"GDF '{layer_name}' hat kein CRS - setze auf {crs}")
        gdf_layer = gdf_layer.set_crs(crs)
    elif gdf_layer.crs.to_string() != crs:
        print(f"Reprojiziere '{layer_name}' nach {crs}")
        gdf_layer = gdf_layer.to_crs(crs)

    gdf_layer.to_file(EXPORT_GPKG, layer=layer_name, driver="GPKG")
    print(f"Exportiert: {layer_name} -> {EXPORT_GPKG}")


export_gdf = gdf.to_crs(EPSG_4326).copy()
export_layers = {
    "wohnadressen": export_gdf,
    "wohnlagen_score": export_gdf[[col for col in export_gdf.columns if col.startswith("score_") or col in ["geometry"]]],
    "cluster_kmeans": export_gdf[[KMEANS_CLUSTER_COL, "cluster_kmeans", "geometry"]] if KMEANS_CLUSTER_COL in export_gdf.columns else None,
    "cluster_kmeans_original": export_gdf[[KMEANS_CLUSTER_COL, "geometry"]] if KMEANS_CLUSTER_COL in export_gdf.columns else None,
    "cluster_kmeans_block": export_gdf[[KMEANS_BLOCK_CLUSTER_COL, KMEANS_BLOCK_CHANGED_COL, "geometry"]] if KMEANS_BLOCK_CLUSTER_COL in export_gdf.columns else None,
    "cluster_skater": export_gdf[["cluster_skater", "geometry"]] if "cluster_skater" in export_gdf.columns else None,
    "cluster_skater_block": export_gdf[["cluster_skater_block", "cluster_skater_block_changed_vs_kmeans", "geometry"]] if "cluster_skater_block" in export_gdf.columns else None,
    "lageklassen": export_gdf[["lageklasse", "score_total", "geometry"]] if "lageklasse" in export_gdf.columns else None,
    "block_kmeans_regions": gdf_blocks_kmeans_map[["block", "address_count", KMEANS_BLOCK_CLUSTER_COL, "geometry"]] if 'gdf_blocks_kmeans_map' in globals() else None,
    "block_skater_regions": gdf_blocks_skater_map[["block", "address_count", "cluster_skater_block", "geometry"]] if 'gdf_blocks_skater_map' in globals() else None,
    "bahnlinien": rails,
    "haltestellen": gdf_haltestellen if 'gdf_haltestellen' in globals() else None,
    "bahnschnitt_debug": export_gdf[["behind_rail_from_center", "center_route", "geometry"]] if "behind_rail_from_center" in export_gdf.columns else None,
}

print("Exportiere alle Layer ...\n")
for layer_name, layer_gdf in export_layers.items():
    write_layer(layer_gdf, layer_name)

print("\nFertig. Die GeoPackage-Datei liegt hier:")
print(EXPORT_GPKG)
export_csv = export_gdf.drop(columns=["geometry"], errors="ignore")
export_csv.to_csv(EXPORT_CSV, index=False, encoding="utf-8")
print(f"CSV exportiert: {EXPORT_CSV}")

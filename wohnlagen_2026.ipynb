# %% [markdown]
# # Datenvorbereitung
# Das Notebook lädt vorberechnete Routing-, Geometrie- und Typologiedaten, vereinheitlicht die Adressschlüssel und führt die Merkmale adressgenau zusammen. Geocoding, CRS-Transformation und ORS-Routing erfolgen in separaten Skripten.

# %%
import warnings
import os

warnings.simplefilter(action="ignore", category=FutureWarning)
import geopandas as gpd
import pandas as pd
from shapely.geometry import box

import helper
from importlib import reload

reload(helper)
from helper import load_geocsv, make_merge_addr, s

# Konfiguration
VERBOSE = False # Debug-Informationen anzeigen (Default: False)

# Zentrale Modellfaktoren: diese Dictionaries steuern Score, Clusterfeatures, Hover und Export.
SCORE_COMPONENT_WEIGHTS = {
    "score_zentralitaet": 1.0 / 3.0,
    "score_versorgung": 1.0 / 3.0,
    "score_mobilitaet": 1.0 / 3.0,
}

SCORE_SUBWEIGHTS = {
    "score_zentralitaet": {"z_centrality": 1.0},
    "score_versorgung": {
        "z_einzelhandel_distance": 0.50,
        "z_einzelhandel_near_500": 0.50,
    },
    "score_mobilitaet": {
        "z_haltestelle_distance": 1.0 / 3.0,
        "z_haltestellen_count_within_500m": 1.0 / 3.0,
        "z_haltestellen_linien_count": 1.0 / 3.0,
    },
}

PENALTY_CONFIG = {
    "z_noise_penalty": {
        "source_col": "laerm_index_tag",
        "factor": 0.40,
        "mode": "above_average_only",
        "label": "Lärm-Malus",
    },
    "z_rail_penalty": {
        "source_col": "behind_rail_from_center",
        "factor": 0.35,
        "mode": "binary_barrier",
        "label": "Bahnbarriere-Malus",
    },
}
CLUSTER_PENALTY_TARGET_SHARE = 0.15


def derive_score_feature_weights(component_weights, subweights):
    weights = {}
    for score_col, component_weight in component_weights.items():
        for feature_col, subweight in subweights.get(score_col, {}).items():
            weights[feature_col] = weights.get(feature_col, 0.0) + component_weight * subweight
    return weights


def derive_cluster_feature_target_shares(component_weights, subweights, penalty_config, penalty_target_share):
    if not 0 <= penalty_target_share < 1:
        raise ValueError("penalty_target_share muss im Intervall [0, 1) liegen")

    score_weights = derive_score_feature_weights(component_weights, subweights)
    score_weight_sum = sum(score_weights.values())
    if score_weight_sum <= 0:
        raise ValueError("Score-Gewichte duerfen nicht leer oder <= 0 sein")

    score_scale = (1.0 - penalty_target_share) / score_weight_sum
    target_shares = {col: weight * score_scale for col, weight in score_weights.items()}

    penalty_factors = {
        penalty_col: abs(float(config.get("factor", 0.0)))
        for penalty_col, config in penalty_config.items()
    }
    penalty_factor_sum = sum(penalty_factors.values())
    if penalty_target_share > 0 and penalty_factor_sum <= 0:
        raise ValueError("Penalty-Zielanteil > 0 erfordert positive Penalty-Faktoren")

    for penalty_col, factor in penalty_factors.items():
        target_shares[penalty_col] = penalty_target_share * factor / penalty_factor_sum if penalty_factor_sum else 0.0
    return target_shares


# Cluster-Zielanteile werden aus dem Scoring abgeleitet und spaeter auf Blockebene varianzkalibriert.
CLUSTER_FEATURE_TARGET_SHARES = derive_cluster_feature_target_shares(
    SCORE_COMPONENT_WEIGHTS,
    SCORE_SUBWEIGHTS,
    PENALTY_CONFIG,
    CLUSTER_PENALTY_TARGET_SHARE,
)

DEFAULT_CLUSTER_COUNT = 3
CLUSTER_EXPORT_RANGE = range(3, 6)


# ----- Ab hier nur noch Detail-Konfiguration ------
EPSG_4326 = "EPSG:4326"
CITY_BOUNDING_BOX = box(12.3120236786, 52.2938432979, 12.7562682548, 52.5594777244)
CITY_CENTER = (52.4116351153561, 12.556331280534392)  # Jahrtausendbrücke

FREISTEHENDE_BUILDING_TYPES = {
    "Freistehendes EFH",
    "EFH: Reihenhaus",
    "EFH: DHH",
    "Freistehendes ZWH",
    "Freistehendes ZFH",
    "ZFH: DHH",
}

SKATER_BLOCK_FLOOR = 8
SKATER_BLOCK_MIN_COMPONENT_SIZE = SKATER_BLOCK_FLOOR + 1
SKATER_UNCLUSTERABLE_BRIDGE_STEPS = 1
SKATER_UNCLUSTERABLE_BLOCKS_CSV = "out/skater_unclusterbare_bloecke_2026.csv"
SKATER_UNCLUSTERABLE_ADDRESSES_CSV = "out/skater_unclusterbare_adressen_2026.csv"

MAP_EXPORT_TEMPLATE = "maps/brb_{n_clusters}_clusters_26.html"
ENABLE_POI_ROUTES_IN_CLUSTER_MAPS = True

CLUSTER_PALETTE = [
    "#1f77b4",
    "#ff7f0e",
    "#2ca02c",
    "#d62728",
    "#9467bd",
    "#8c564b",
    "#e377c2",
]
SKATER_PALETTE = CLUSTER_PALETTE
FREISTEHEND_LAYER_COLOR = "#b58900"

POI_ROUTE_CONFIGS = [
    {
        "route_col": "center_route",
        "distance_col": "center_distance",
        "label": "Weg zum Zentrum",
        "color": "#95a5a6",
        "marker_color": "lightgray",
        "icon": "bullseye",
        "fallback": "Z",
    },
    {
        "route_col": "haltestellen_route",
        "distance_col": "haltestellen_min_distance",
        "target_col": "haltestellen_target_name",
        "label": "Nächste Haltestelle",
        "color": "#d9a441",
        "marker_color": "beige",
        "icon": "bus",
        "fallback": "H",
    },
    {
        "route_col": "einzelhandel_route",
        "distance_col": "einzelhandel_min_distance",
        "target_col": "einzelhandel_target_name",
        "label": "Nächster Einzelhandel",
        "color": "#8e44ad",
        "marker_color": "purple",
        "icon": "shopping-cart",
        "fallback": "E",
    },
]

EXPORT_PATH = "out"
EXPORT_GPKG = os.path.join(EXPORT_PATH, "wohnlagen_brb_2026.gpkg")
EXPORT_CSV = os.path.join(EXPORT_PATH, "wohnlagen_brb_2026.csv")

# %% [markdown]
# ## Adressen einlesen und vorbereiten
# Die adressbezogenen Zentrumsrouten werden geladen, in `center_route` und `center_distance` umbenannt und über `Adresse_merge` dedupliziert. Zusätzlich wird jede Adresse per Spatial Join einem Block aus `data/2026-02-12-Blockgrenzen.gpkg` zugeordnet.

# %%
gdf = load_geocsv("out/adressen_mit_zentrum_routen.csv")
gdf = gdf.rename(columns={"geojson": "center_route", "distance_m": "center_distance"})
gdf = gdf.drop(columns=["duration_s", "display_name", "type", "category", "Adresse_query"], errors="ignore")

# Adressen ohne Geometrie entfernen
gdf = gdf[~gdf.geometry.isna()].copy()
gdf["Adresse_merge"] = gdf.apply(make_merge_addr, axis=1)
gdf = gdf.drop_duplicates(subset=["Adresse_merge"]).copy()

gdf_blockgrenzen = gpd.read_file("data/2026-02-12-Blockgrenzen.gpkg")[["BLOCK", "geometry"]].rename(columns={"BLOCK": "block"})
gdf_blockgrenzen = gdf_blockgrenzen.to_crs(gdf.crs)
gdf = gdf.drop(columns=["index_right", "block"], errors="ignore")
gdf = gpd.sjoin(
    gdf,
    gdf_blockgrenzen,
    how="left",
    predicate="within",
)
gdf = gdf.drop(columns=["index_right"], errors="ignore")

if VERBOSE:
    dups = gdf[gdf.duplicated(subset=["Adresse_merge"], keep=False)]
    print(f"{len(dups)} doppelte Adressen gefunden")
    display(dups.head())
    print(gdf.shape)

# %%
# Gebäudetypologie ergänzen
gdf_typologie = pd.read_csv("data/Gebaeudetypologie.csv")

# Quellen sind je nach Datenstand unterschiedlich benannt; robust auflösen.
type_source_col = next(
    (c for c in ["Typologie", "typologie", "GEBTYPGROESSE"] if c in gdf_typologie.columns),
    None,
)
age_source_col = next(
    (c for c in ["Baualtersklassen_Zensus", "Baualtersklassen_Stadt"] if c in gdf_typologie.columns),
    None,
)
if type_source_col is None:
    raise KeyError("Keine Typologiespalte gefunden (erwartet: Typologie oder GEBTYPGROESSE).")
if age_source_col is None:
    raise KeyError("Keine Baualtersklassenspalte gefunden.")

rename_map = {
    type_source_col: "building_type",
    age_source_col: "building_age_class",
}
gdf_typologie = gdf_typologie.rename(columns=rename_map)

if "Baualtersklassen_Stadt" in gdf_typologie.columns and age_source_col != "Baualtersklassen_Stadt":
    gdf_typologie["building_age_class"] = gdf_typologie["building_age_class"].fillna(gdf_typologie["Baualtersklassen_Stadt"])

# Fallback: Wenn Typologie unbekannt ist, Gebäudetyp (EFH/ZFH/ZWH) als freistehend mappen.
fallback_source_col = next(
    (c for c in ["Gebäudetyp", "Gebaeudetyp", "gebaeudetyp"] if c in gdf_typologie.columns),
    None,
)

fallback_assigned_count = 0
if fallback_source_col is not None:
    def _map_freistehend_from_gebaeudetyp(value):
        text = str(value).strip().lower()
        if text in {"", "nan", "none"}:
            return None
        text = (
            text.replace("ä", "ae")
            .replace("ö", "oe")
            .replace("ü", "ue")
            .replace("ß", "ss")
        )
        if "efh" in text or "einfamil" in text:
            return "Freistehendes EFH"
        if "zfh" in text or "zwh" in text or "zweifamil" in text:
            return "Freistehendes ZWH"
        return None

    typology_unknown_mask = gdf_typologie["building_type"].astype(str).str.strip().str.lower().isin({"", "nan", "none", "unbekannt"})
    fallback_values = gdf_typologie[fallback_source_col].map(_map_freistehend_from_gebaeudetyp)
    fallback_mask = typology_unknown_mask & fallback_values.notna()
    fallback_assigned_count = int(fallback_mask.sum())
    gdf_typologie.loc[fallback_mask, "building_type"] = fallback_values.loc[fallback_mask]

gdf_typologie["Adresse_merge"] = gdf_typologie.apply(make_merge_addr, axis=1)
gdf_typologie = gdf_typologie.sort_values("Adresse_merge").drop_duplicates("Adresse_merge", keep="first")

typologie_attributes = ["building_type", "building_age_class"]
gdf = gdf.drop(columns=typologie_attributes + ["is_freistehend_building"], errors="ignore")
gdf = pd.merge(
    gdf,
    gdf_typologie[["Adresse_merge"] + typologie_attributes],
    on="Adresse_merge",
    how="left",
    validate="one_to_one",
)
typology_missing = int(gdf["building_type"].isna().sum())
gdf[typologie_attributes] = gdf[typologie_attributes].fillna("unbekannt")

gdf["is_freistehend_building"] = gdf["building_type"].isin(FREISTEHENDE_BUILDING_TYPES)

print(f"Fehlende Typologien nach Merge: {typology_missing}")
print(f"Fallback-Zuordnungen über Gebäudetyp: {fallback_assigned_count}")
print(gdf["building_type"].value_counts(dropna=False).head())
print(gdf["is_freistehend_building"].value_counts(dropna=False))
# Out:
# Fehlende Typologien nach Merge: 3007
# Fallback-Zuordnungen über Gebäudetyp: 0
# building_type
# Freistehendes EFH      5267
# unbekannt              3007
# MFH: 7-12 Wohnungen    1987
# MFH: 3-6 Wohnungen     1969
# EFH: Reihenhaus        1777
# Name: count, dtype: int64
# is_freistehend_building
# True     9090
# False    7828
# Name: count, dtype: int64

# %% [markdown]
# ## Einzelhandel
# Die Koordinaten der Einzelhandelsstandorte werden aus `data/2026_Einzelhandel.csv` mit `crs-conversion.py` nach WGS84 transformiert. Danach erzeugt `routing.py` per lokalem ORS die Datei `out/adressen_mit_einzelhandel_routen.csv`.
#
# Verwendete Faktoren:
# - Geringste Distanz und Route zum nächsten Einzelhandelsstandort
# - Name des nächsten Einzelhandelsstandorts
# - Anzahl der Einkaufsmöglichkeiten im Umkreis von 500 m

# %%
gdf_retail = load_geocsv("out/adressen_mit_einzelhandel_routen.csv")
gdf_retail["Adresse_merge"] = gdf_retail.apply(make_merge_addr, axis=1)
gdf_retail = gdf_retail.sort_values("Adresse_merge").drop_duplicates("Adresse_merge", keep="first")

einzelhandel_attribute = [
    "einzelhandel_route",
    "einzelhandel_min_distance",
    "einzelhandel_target_name",
    "einzelhandel_count_within_500m",
]
gdf = gdf.drop(columns=einzelhandel_attribute, errors="ignore")
gdf = pd.merge(
    gdf,
    gdf_retail[["Adresse_merge"] + einzelhandel_attribute],
    on="Adresse_merge",
    how="left",
    validate="one_to_one",
)

if VERBOSE:
    print("gdf_retail shape:", gdf_retail.shape)
    print("gdf shape (nach Einzelhandel-Merge):", gdf.shape)

del gdf_retail

# %% [markdown]
# ## Lärmbelastung
# Die Lärmbelastung wird aus `out/adressen_mit_laerm.csv` über `Adresse_merge` ergänzt. Fehlende Werte stehen für keine gemessene Straßenlärmbelastung und werden im Lärmmalus neutral behandelt.
#
# Definition Lärm-Index:
# - leer: kein gemessener Straßenlärm
# - 0: 55 - 59 dB
# - 1: 60 - 64 dB
# - 2: 65 - 69 dB
# - 3: 70 - 74 dB
# - 4: >= 75 dB

# %%
gdf_laerm_karte = load_geocsv("out/adressen_mit_laerm.csv")
if VERBOSE:
    print(gdf_laerm_karte.shape)
    print(gdf.shape)

# Merge des Lärmindex mit Haupt-GDF
gdf_laerm_karte["Adresse_merge"] = gdf_laerm_karte.apply(make_merge_addr, axis=1)
gdf_laerm_karte["laerm_index_tag"] = pd.to_numeric(gdf_laerm_karte["Laerm_index_tag"], errors="coerce")

# Deduplicate, im Zweifel nimm den lautesten Wert
gdf_laerm_karte = (
    gdf_laerm_karte
    .sort_values("laerm_index_tag", ascending=False)
    .drop_duplicates("Adresse_merge", keep="first")
)

laerm_attribute = ["laerm_index_tag"]
gdf = pd.merge(
    gdf,
    gdf_laerm_karte[["Adresse_merge"] + laerm_attribute],
    on="Adresse_merge",
    how="left",
    validate="one_to_many"
)

if VERBOSE:
    print(gdf.shape)

# %% [markdown]
# ## ÖPNV-Haltestellen
# Für die ÖPNV-Bewertung werden die Fußdistanz zur nächsten Haltestelle, der Name der nächsten Haltestelle, die Anzahl der Haltestellen im Umkreis von 500 m und die Anzahl der Linien an der nächsten Haltestelle verwendet.
#
# Die Haltestellen-Koordinaten stammen aus `data/2026_Haltestellen.csv`, werden mit `crs-conversion.py` transformiert und mit `routing.py` zu `out/adressen_mit_haltestellen_routen.csv` weiterverarbeitet.

# %%
import pandas as pd
import geopandas as gpd

gdf_haltestellen = load_geocsv("out/adressen_mit_haltestellen_routen.csv")
gdf_haltestellen["Adresse_merge"] = gdf_haltestellen.apply(make_merge_addr, axis=1)
gdf_haltestellen = gdf_haltestellen.drop_duplicates("Adresse_merge").copy()
gdf_haltestellen = gdf_haltestellen.rename(columns={"Anzahl der Linien": "haltestellen_linien_count", "linien_count": "haltestellen_linien_count"})

if VERBOSE:
    print("gdf_haltestellen shape:", gdf_haltestellen.shape)
    print("gdf shape (vor Merge):", gdf.shape)

# Merge haltestellen attributes into main GeoDataFrame
haltestellen_attribute = ["haltestellen_route", "haltestellen_min_distance", "haltestellen_target_name", "haltestellen_count_within_500m", "haltestellen_linien_count"]
gdf = pd.merge(
    gdf,
    gdf_haltestellen[["Adresse_merge"] + haltestellen_attribute],
    on="Adresse_merge",
    how="left",
    validate="one_to_one"
)

if VERBOSE:
    print("gdf shape (nach Merge):", gdf.shape)

# %% [markdown]
# ## Begrenzung durch dauerhafte Barrieren
# Es wird geprüft, ob die Fußroute zum Stadtzentrum eine OSM-Bahnlinie schneidet. Daraus entsteht `behind_rail_from_center`; im Scoring wird daraus später `z_rail_penalty` als moderater Mobilitätsmalus abgeleitet.

# %%
import json
import osmnx as ox
from shapely.geometry import LineString
# Schritt 1: Bahnlinien von OSM laden
place = "Brandenburg an der Havel, Germany"

# Eisenbahnlinien holen
rails = ox.features_from_place(
    place,
    tags={"railway": True}  # includes rail, light_rail, tram, etc.
)

# nur Schienenverkehr (keine Haltestellen)
rails = rails[rails["railway"].isin(["rail"])]
gdf.crs = EPSG_4326
rails.crs = EPSG_4326

# Schritt 2: Fußĺäufige Routen zum Stadtzentrum auf Schnittpunkt mit Bahnlinie prüfen und im Datensatz speichern
def route_crosses_rail(route_geojson_str, rail_geom):
    if not isinstance(route_geojson_str, str):
        return False

    try:
        geo = json.loads(route_geojson_str)
    except (json.JSONDecodeError, TypeError, ValueError):
        return False

    if geo.get("type") != "LineString":
        return False

    # Koordinaten (lon, lat) -> Shapely LineString nutzen
    coords = geo["coordinates"]
    line = LineString(coords)

    # Schnitt-Test
    return line.intersects(rail_geom)

rail_union = rails.union_all()
gdf["behind_rail_from_center"] = gdf["center_route"].apply(
    lambda r: int(route_crosses_rail(r, rail_union))
)

if VERBOSE:
    print(gdf.shape)

# %% [markdown]
# # Scoring / Punktesystem
# Die Score-Gewichte sind in der Konfigurationszelle definiert. Die einzelnen Teil-Scores sind standardisierte Bewertungen auf z-Wert-Basis; positive Werte liegen über dem Durchschnitt, negative darunter. Die Gewichte erzeugen keine eigenen Messwerte, sondern steuern nur, wie stark die vorhandenen Teil-Scores in `score_total` eingehen. Der Gesamtscore kombiniert Zentralität, Versorgung und Mobilität; Lärm und Bahnbarriere wirken zusätzlich als Malus. Für das Clustering werden die Zielanteile aus dem Scoring abgeleitet und auf Blockebene varianzkalibriert, damit die tatsächliche Distanzwirkung der Features den fachlichen Zielanteilen entspricht.

# %%
import numpy as np
from scipy.stats import zscore

numeric_features = [
    "center_distance",
    "einzelhandel_min_distance",
    "einzelhandel_count_within_500m",
    "haltestellen_min_distance",
    "haltestellen_count_within_500m",
    "haltestellen_linien_count",
    "laerm_index_tag",
]
missing_numeric_features = [col for col in numeric_features if col not in gdf.columns]
if missing_numeric_features:
    raise ValueError(f"Diese numerischen Features fehlen im gdf: {missing_numeric_features}")


def safe_z(x):
    z = zscore(x)
    return np.where(np.isfinite(z), z, 0)


def assign_z(target_col, source_col, direction=1, fill_missing=None):
    gdf[target_col] = np.nan
    mask = gdf[source_col].notna()
    if mask.any():
        gdf.loc[mask, target_col] = direction * safe_z(gdf.loc[mask, source_col])
    if fill_missing is not None:
        gdf[target_col] = gdf[target_col].fillna(fill_missing)
    return mask


def weighted_sum(df, weights):
    cols = list(weights)
    missing = [col for col in cols if col not in df.columns]
    if missing:
        raise ValueError(f"Fehlende Score-Spalten: {missing}")
    mask = df[cols].notna().all(axis=1)
    values = sum(weight * df.loc[mask, col] for col, weight in weights.items())
    return mask, values


def scale_score(z):
    if pd.isna(z):
        return np.nan
    score = (z + 3) / 6 * 10
    return max(0, min(10, round(score, 1)))

# Z-Scores: höhere Werte bedeuten bessere bzw. stärkere Lageausprägung.
assign_z("z_centrality", "center_distance", direction=-1)
assign_z("z_einzelhandel_distance", "einzelhandel_min_distance", direction=-1)
assign_z("z_einzelhandel_near_500", "einzelhandel_count_within_500m")
assign_z("z_laerm_index_tag", "laerm_index_tag", direction=-1, fill_missing=0)
assign_z("z_haltestelle_distance", "haltestellen_min_distance", direction=-1)
assign_z("z_haltestellen_count_within_500m", "haltestellen_count_within_500m")
assign_z("z_haltestellen_linien_count", "haltestellen_linien_count")

# Strafterme: Lärm und Bahnbarriere gehen genau einmal als Malus in score_total ein.
gdf["z_noise_penalty"] = 0.0
noise_source_col = PENALTY_CONFIG["z_noise_penalty"]["source_col"]
noise_mask = gdf[noise_source_col].notna()
if noise_mask.any():
    noise_z_raw = pd.Series(safe_z(gdf.loc[noise_mask, noise_source_col]), index=gdf.loc[noise_mask].index)
    gdf.loc[noise_mask, "z_noise_penalty"] = -PENALTY_CONFIG["z_noise_penalty"]["factor"] * noise_z_raw.clip(lower=0)
gdf["z_rail_penalty"] = -PENALTY_CONFIG["z_rail_penalty"]["factor"] * gdf["behind_rail_from_center"].fillna(0).astype(float)

missing_cluster_feature_cols = [col for col in CLUSTER_FEATURE_TARGET_SHARES if col not in gdf.columns]
if missing_cluster_feature_cols:
    raise ValueError(f"Diese Cluster-Variablen fehlen im gdf: {missing_cluster_feature_cols}")

for score_col, subweights in SCORE_SUBWEIGHTS.items():
    mask, values = weighted_sum(gdf, subweights)
    gdf.loc[mask, score_col] = values

score_component_cols = list(SCORE_COMPONENT_WEIGHTS)
penalty_cols = list(PENALTY_CONFIG)
mask_all_scores = gdf[score_component_cols + penalty_cols].notna().all(axis=1)
gdf.loc[mask_all_scores, "score_total"] = sum(
    weight * gdf.loc[mask_all_scores, col]
    for col, weight in SCORE_COMPONENT_WEIGHTS.items()
)
for penalty_col in penalty_cols:
    gdf.loc[mask_all_scores, "score_total"] += gdf.loc[mask_all_scores, penalty_col]

# Diagnosewert: zeigt Lärm als Umweltkomponente, wird aber nicht zusätzlich in score_total gewichtet.
gdf["score_umwelt_diagnose"] = gdf["z_laerm_index_tag"]

for score_col in ["score_total", *SCORE_COMPONENT_WEIGHTS, "score_umwelt_diagnose"]:
    if score_col in gdf.columns:
        gdf[f"{score_col}_scaled"] = gdf[score_col].apply(scale_score)

if VERBOSE:
    print("Anzahl gültiger Gesamt-Scores:", gdf["score_total"].notna().sum())
    display(gdf[["score_total", *SCORE_COMPONENT_WEIGHTS, *penalty_cols]].corr())

# %% [markdown]
# # Räumliches Clustering
# Die Wohnlagen werden mit SKATER auf Blockebene gebildet. Dafür werden die adressbezogenen z-Variablen je Block aggregiert; Blöcke oder Adressen ohne vollständige Clustermerkmale werden separat nach `out/` exportiert.

# %%
import os
import numpy as np
from libpysal.weights import Rook, W
from spopt.region import Skater


gdf = gdf.to_crs(epsg=32633).copy().reset_index(drop=True)
if "address_id" not in gdf.columns:
    gdf["address_id"] = gdf.index.astype(int)

missing_block_rows = int(gdf["block"].isna().sum())
if missing_block_rows > 0:
    print(f"WARNUNG: {missing_block_rows} Adressen ohne Blockzuordnung werden für Block-SKATER ignoriert.")


def summarize_weights(W, label):
    component_sizes = pd.Series(W.component_labels).value_counts().sort_values()
    smallest_component = int(component_sizes.iloc[0])
    largest_component = int(component_sizes.iloc[-1])
    if VERBOSE:
        print(
            f"{label}: n_components={W.n_components}, min_component_size={smallest_component}, "
            f"max_component_size={largest_component}, islands={len(W.islands)}"
        )
    return smallest_component


def build_block_weights(gdf_polygons, clusterable_mask, min_component_size, bridge_steps=SKATER_UNCLUSTERABLE_BRIDGE_STEPS):
    gdf_polygons = gdf_polygons.reset_index(drop=True)
    clusterable_mask = pd.Series(clusterable_mask).reset_index(drop=True).astype(bool)
    clusterable_positions = set(np.flatnonzero(clusterable_mask.to_numpy()))
    local_position = {pos: local_idx for local_idx, pos in enumerate(sorted(clusterable_positions))}

    W_rook_all = Rook.from_dataframe(gdf_polygons, use_index=False).symmetrize()
    local_neighbors = {local_idx: set() for local_idx in local_position.values()}
    direct_edges = set()
    bridge_edges = set()

    for pos, local_idx in local_position.items():
        for neighbor_pos in W_rook_all.neighbors.get(pos, []):
            if neighbor_pos in clusterable_positions:
                neighbor_local_idx = local_position[neighbor_pos]
                local_neighbors[local_idx].add(neighbor_local_idx)
                direct_edges.add(tuple(sorted((local_idx, neighbor_local_idx))))
            elif bridge_steps >= 1:
                for bridged_pos in W_rook_all.neighbors.get(neighbor_pos, []):
                    if bridged_pos in clusterable_positions and bridged_pos != pos:
                        bridged_local_idx = local_position[bridged_pos]
                        local_neighbors[local_idx].add(bridged_local_idx)
                        bridge_edges.add(tuple(sorted((local_idx, bridged_local_idx))))

    local_neighbors = {idx: sorted(neighbors) for idx, neighbors in local_neighbors.items()}
    W_rook = W(local_neighbors).symmetrize()
    added_bridge_edges = bridge_edges - direct_edges
    weights_label = f"Rook + {len(added_bridge_edges)} Brücken über leere Blöcke"
    smallest_component = summarize_weights(W_rook, weights_label)
    if smallest_component >= min_component_size:
        return W_rook, weights_label
    raise ValueError(
        f"Rook-Kontiguität mit Brücken nicht geeignet: kleinste Komponente kleiner als floor={min_component_size}."
    )


def add_variance_calibrated_cluster_features(gdf_blocks, feature_target_shares, valid_mask):
    """Skaliert Clusterfeatures so, dass ihre Block-Varianz den Zielanteilen entspricht."""
    feature_cols = list(feature_target_shares)
    feature_variance = gdf_blocks.loc[valid_mask, feature_cols].var(ddof=0)
    diagnostics_rows = []

    gdf_result = gdf_blocks.copy()
    for source_col, target_share in feature_target_shares.items():
        raw_variance = float(feature_variance[source_col])
        if target_share > 0 and (not np.isfinite(raw_variance) or raw_variance <= 0):
            raise ValueError(f"Cluster-Feature '{source_col}' hat keine Varianz, aber Zielanteil {target_share:.3f}")

        # SKATER nutzt euklidische Distanzen; Multiplikation mit sqrt(w) erzeugt den Distanzbeitrag w * Varianz.
        scaling_weight = target_share / raw_variance if target_share > 0 else 0.0
        weighted_col = f"weighted_{source_col}"
        gdf_result[weighted_col] = np.sqrt(scaling_weight) * gdf_result[source_col]
        effective_weighted_variance = scaling_weight * raw_variance if np.isfinite(raw_variance) else np.nan

        diagnostics_rows.append({
            "feature": source_col,
            "target_share": target_share,
            "raw_std": np.sqrt(raw_variance) if np.isfinite(raw_variance) else np.nan,
            "raw_variance": raw_variance,
            "scaling_weight": scaling_weight,
            "effective_weighted_variance": effective_weighted_variance,
        })

    diagnostics = pd.DataFrame(diagnostics_rows)
    total_effective_variance = diagnostics["effective_weighted_variance"].sum()
    diagnostics["effective_share"] = (
        diagnostics["effective_weighted_variance"] / total_effective_variance
        if total_effective_variance else np.nan
    )
    return gdf_result, diagnostics


cluster_feature_cols = list(CLUSTER_FEATURE_TARGET_SHARES)
missing_cluster_feature_cols = [col for col in cluster_feature_cols if col not in gdf.columns]
if missing_cluster_feature_cols:
    raise ValueError(f"Diese Cluster-Variablen fehlen im gdf: {missing_cluster_feature_cols}")
z_vars = [f"weighted_{col}" for col in cluster_feature_cols]
gdf_skater_base = gdf.drop(
    columns=["cluster_skater_block", "cluster_skater", *z_vars],
    errors="ignore",
).copy()
gdf_blockgrenzen_skater = gpd.read_file("data/2026-02-12-Blockgrenzen.gpkg")[["BLOCK", "geometry"]].rename(columns={"BLOCK": "block"})
gdf_blockgrenzen_skater = gdf_blockgrenzen_skater.to_crs(gdf.crs)
block_feature_aggs = {"address_count": ("block", "size")}
block_feature_aggs.update({col: (col, "mean") for col in cluster_feature_cols})
block_features = (
    gdf_skater_base.dropna(subset=["block"])
    .groupby("block", as_index=False)
    .agg(**block_feature_aggs)
)
gdf_blocks_skater_merged = gdf_blockgrenzen_skater.merge(block_features, on="block", how="left")
block_required_cols = ["address_count"] + cluster_feature_cols
mask_block_complete = gdf_blocks_skater_merged[block_required_cols].notna().all(axis=1)
dropped_block_rows = int((~mask_block_complete).sum())
if dropped_block_rows > 0:
    print(f"WARNUNG: {dropped_block_rows} Blöcke ohne vollständige aggregierte z-Werte vor Block-SKATER entfernt.")

gdf_blocks_unclusterable = gdf_blocks_skater_merged.loc[~mask_block_complete].copy()
if not gdf_blocks_unclusterable.empty:
    missing_matrix = gdf_blocks_unclusterable[block_required_cols].isna()
    gdf_blocks_unclusterable["skater_unclusterable_reason"] = "fehlende_aggregierte_skater_features"
    gdf_blocks_unclusterable["missing_feature_count"] = missing_matrix.sum(axis=1)
    gdf_blocks_unclusterable["missing_features"] = missing_matrix.apply(
        lambda row: ", ".join([col for col, is_missing in row.items() if is_missing]),
        axis=1,
    )

gdf_blocks_skater_merged, cluster_feature_weight_diagnostics = add_variance_calibrated_cluster_features(
    gdf_blocks_skater_merged,
    CLUSTER_FEATURE_TARGET_SHARES,
    mask_block_complete,
)
os.makedirs("plots", exist_ok=True)
cluster_feature_weight_diagnostics.to_csv(
    "plots/cluster_feature_weight_diagnostics.csv",
    index=False,
    encoding="utf-8",
)
display(cluster_feature_weight_diagnostics.round(4))

gdf_blocks_skater_base = gdf_blocks_skater_merged.loc[mask_block_complete].copy().reset_index(drop=True)


def run_block_skater_for_n_clusters(n_clusters, verbose=VERBOSE):
    gdf_blocks_result = gdf_blocks_skater_base.copy()
    W_blocks, weights_label = build_block_weights(
        gdf_blocks_skater_merged,
        clusterable_mask=mask_block_complete,
        min_component_size=SKATER_BLOCK_MIN_COMPONENT_SIZE,
    )
    if verbose:
        print(
            "Block-SKATER:",
            "blocks=", len(gdf_blocks_result),
            "weights=", weights_label,
            "clusters=", n_clusters,
        )

    sk_blocks = Skater(
        gdf_blocks_result,
        W_blocks,
        z_vars,
        n_clusters=n_clusters,
        islands="increase",
        floor=SKATER_BLOCK_FLOOR,
    )
    sk_blocks.solve()
    gdf_blocks_result["cluster_skater_block"] = sk_blocks.labels_.astype(int)

    gdf_result = gdf_skater_base.drop(
        columns=["cluster_skater_block", "cluster_skater"],
        errors="ignore",
    ).merge(
        gdf_blocks_result[["block", "cluster_skater_block"]],
        on="block",
        how="left",
        validate="many_to_one",
    )
    return gdf_result, gdf_blocks_result, weights_label
def compile_cluster_results(n_clusters, verbose=VERBOSE):
    gdf_result, gdf_blocks_result, block_weights_label = run_block_skater_for_n_clusters(
        n_clusters,
        verbose=verbose,
    )
    gdf_result["cluster_skater_block"] = gdf_result["cluster_skater_block"].astype("Int64")
    gdf_result["cluster_skater"] = gdf_result["cluster_skater_block"]

    meta = {
        "n_clusters": n_clusters,
        "block_weights_label": block_weights_label,
    }
    return gdf_result, gdf_blocks_result, meta


gdf, gdf_blocks_skater, skater_meta = compile_cluster_results(DEFAULT_CLUSTER_COUNT)

os.makedirs("out", exist_ok=True)

block_export_cols = [
    "block",
    "address_count",
    "skater_unclusterable_reason",
    "missing_feature_count",
    "missing_features",
    "geometry",
]
if gdf_blocks_unclusterable.empty:
    empty_block_export = pd.DataFrame(columns=block_export_cols)
    empty_block_export.to_csv(SKATER_UNCLUSTERABLE_BLOCKS_CSV, index=False, encoding="utf-8")
else:
    gdf_blocks_unclusterable_export = gdf_blocks_unclusterable.copy()
    gdf_blocks_unclusterable_export["geometry"] = gdf_blocks_unclusterable_export.geometry.apply(
        lambda geom: geom.wkt if geom is not None else None
    )
    gdf_blocks_unclusterable_export = gdf_blocks_unclusterable_export[block_export_cols]
    gdf_blocks_unclusterable_export.to_csv(SKATER_UNCLUSTERABLE_BLOCKS_CSV, index=False, encoding="utf-8")

unclusterable_block_ids = set(gdf_blocks_unclusterable["block"].dropna().astype(str))
gdf_unclusterable_addresses = gdf[gdf["cluster_skater_block"].isna()].copy()
if not gdf_unclusterable_addresses.empty:
    gdf_unclusterable_addresses["skater_unclusterable_reason"] = np.where(
        gdf_unclusterable_addresses["block"].isna(),
        "keine_blockzuordnung",
        np.where(
            gdf_unclusterable_addresses["block"].astype(str).isin(unclusterable_block_ids),
            "block_unclusterbar",
            "nicht_von_skater_zugeordnet",
        ),
    )

address_export_cols = [
    "address_id",
    "Straßenname",
    "Hsnr",
    "HsnrZus",
    "Adresse_merge",
    "block",
    "cluster_skater_block",
    "skater_unclusterable_reason",
    "lat",
    "lon",
    "geometry",
]
available_address_cols = [col for col in address_export_cols if col in gdf_unclusterable_addresses.columns]
if "geometry" in available_address_cols:
    gdf_unclusterable_addresses["geometry"] = gdf_unclusterable_addresses.geometry.apply(
        lambda geom: geom.wkt if geom is not None else None
    )

if gdf_unclusterable_addresses.empty:
    pd.DataFrame(columns=[col for col in address_export_cols if col != "geometry"] + ["geometry"]).to_csv(
        SKATER_UNCLUSTERABLE_ADDRESSES_CSV,
        index=False,
        encoding="utf-8",
    )
else:
    gdf_unclusterable_addresses[available_address_cols].to_csv(
        SKATER_UNCLUSTERABLE_ADDRESSES_CSV,
        index=False,
        encoding="utf-8",
    )

if VERBOSE:
    print(
        f"SKATER aktuell im Notebook berechnet für k={DEFAULT_CLUSTER_COUNT}. "
        f"Block-Gewichte={skater_meta['block_weights_label']}."
    )
# Out:
# WARNUNG: 42 Blöcke ohne vollständige aggregierte z-Werte vor Block-SKATER entfernt.
#                             feature  target_share  raw_std  raw_variance  \
# 0                      z_centrality        0.2833   1.1115        1.2355
# 1           z_einzelhandel_distance        0.1417   1.1028        1.2161
# 2           z_einzelhandel_near_500        0.1417   0.9367        0.8774
# 3            z_haltestelle_distance        0.0944   1.3560        1.8387
# 4  z_haltestellen_count_within_500m        0.0944   0.9834        0.9670
# 5       z_haltestellen_linien_count        0.0944   0.9729        0.9466
# 6                   z_noise_penalty        0.0800   0.0896        0.0080
# 7                    z_rail_penalty        0.0700   0.1661        0.0276
#
#    scaling_weight  effective_weighted_variance  effective_share
# 0          0.2293                       0.2833           0.2833
# 1          0.1165                       0.1417           0.1417
# ...

# %% [markdown]
# # Silhouette-Diagnose
# Für die Modellwahl werden SKATER-Lösungen mit `k=2` bis `k=7` berechnet und als Silhouette-Plots nach `plots/` exportiert.

# %%
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_samples, silhouette_score


SILHOUETTE_CLUSTER_RANGE = range(2, 8)
plots_dir = Path("plots")
plots_dir.mkdir(parents=True, exist_ok=True)

silhouette_rows = []

for k in SILHOUETTE_CLUSTER_RANGE:
    if k == DEFAULT_CLUSTER_COUNT:
        gdf_blocks_eval = gdf_blocks_skater.copy()
    else:
        _, gdf_blocks_eval, _ = compile_cluster_results(k, verbose=False)

    X_blocks = gdf_blocks_eval[z_vars].to_numpy()
    labels = gdf_blocks_eval["cluster_skater_block"].to_numpy()
    unique_labels = sorted(pd.Series(labels).dropna().astype(int).unique())
    cluster_sizes = gdf_blocks_eval.groupby("cluster_skater_block")["address_count"].sum()

    if len(unique_labels) < 2 or len(unique_labels) >= len(gdf_blocks_eval):
        avg_silhouette = np.nan
        silhouette_values = np.full(len(gdf_blocks_eval), np.nan)
    else:
        avg_silhouette = silhouette_score(X_blocks, labels)
        silhouette_values = silhouette_samples(X_blocks, labels)

    silhouette_rows.append({
        "k": k,
        "silhouette": avg_silhouette,
        "smallest_cluster_addresses": int(cluster_sizes.min()),
        "largest_cluster_addresses": int(cluster_sizes.max()),
        "size_ratio": float(cluster_sizes.max() / cluster_sizes.min()) if cluster_sizes.min() else np.nan,
    })

    fig, ax = plt.subplots(figsize=(8, 5))
    y_lower = 10
    for idx, cluster_id in enumerate(unique_labels):
        values = silhouette_values[labels == cluster_id]
        values = values[np.isfinite(values)]
        values.sort()
        y_upper = y_lower + len(values)
        color = plt.cm.tab10(idx % 10)
        ax.fill_betweenx(
            np.arange(y_lower, y_upper),
            0,
            values,
            facecolor=color,
            edgecolor=color,
            alpha=0.7,
        )
        ax.text(-0.05, y_lower + 0.5 * len(values), str(cluster_id))
        y_lower = y_upper + 10

    ax.axvline(avg_silhouette, color="red", linestyle="--", linewidth=1.5, label=f"Ø {avg_silhouette:.3f}")
    ax.set_title(f"SKATER-Silhouette (k={k})")
    ax.set_xlabel("Silhouette-Koeffizient")
    ax.set_ylabel("Cluster")
    ax.set_yticks([])
    ax.set_xlim(-0.2, 1.0)
    ax.legend(loc="best")
    ax.grid(True, axis="x", alpha=0.25)
    plt.tight_layout()
    plt.savefig(plots_dir / f"skater_silhouette_k{k}.png", dpi=300, bbox_inches="tight")
    plt.close(fig)

silhouette_df = pd.DataFrame(silhouette_rows)
silhouette_df.to_csv(plots_dir / "skater_silhouette_scores_2_7.csv", index=False, encoding="utf-8")

fig, ax = plt.subplots(figsize=(8, 4.8))
ax.plot(silhouette_df["k"], silhouette_df["silhouette"], marker="o", color="steelblue")
ax.axvline(DEFAULT_CLUSTER_COUNT, color="black", linestyle="--", linewidth=1, label=f"gewähltes k={DEFAULT_CLUSTER_COUNT}")
ax.set_title("SKATER-Silhouette nach Clusterzahl")
ax.set_xlabel("Anzahl Cluster (k)")
ax.set_ylabel("Durchschnittlicher Silhouette-Koeffizient")
ax.set_xticks(list(SILHOUETTE_CLUSTER_RANGE))
ax.grid(True, alpha=0.3)
ax.legend()
plt.tight_layout()
plt.savefig(plots_dir / "skater_silhouette_scores_2_7.png", dpi=300, bbox_inches="tight")
plt.show()

display(silhouette_df.round(3))
print(f"Silhouette-Plots exportiert nach: {plots_dir}")
# Out:
# /home/nitze/PycharmProjects/WohnlagenBRB/.venv1/lib/python3.12/site-packages/libpysal/weights/contiguity.py:61: UserWarning: The weights matrix is not fully connected:
#  There are 2 disconnected components.
#  There is 1 island with id: 561.
#   W.__init__(self, neighbors, ids=ids, **kw)
# /home/nitze/PycharmProjects/WohnlagenBRB/.venv1/lib/python3.12/site-packages/libpysal/weights/weights.py:1296: UserWarning: The weights matrix is not fully connected:
#  There are 2 disconnected components.
#  There is 1 island with id: 561.
#   out_w = W(neighbors, weights, id_order=self.id_order)
# /home/nitze/PycharmProjects/WohnlagenBRB/.venv1/lib/python3.12/site-packages/libpysal/weights/contiguity.py:61: UserWarning: The weights matrix is not fully connected:
#  There are 2 disconnected components.
#  There is 1 island with id: 561.
#   W.__init__(self, neighbors, ids=ids, **kw)
# ...

# %% [markdown]
# # Cluster-Karte
# Die Karte visualisiert SKATER-Blockflächen und adressbezogene Clusterpunkte. Beim Klick auf einen Adresspunkt werden die farbigen Fußrouten zum Zentrum, zur nächsten Haltestelle und zum nächsten Einzelhandelsstandort eingeblendet. Freistehende Gebäude können über einen separaten, standardmäßig ausgeblendeten Layer zugeschaltet werden.

# %%
import folium
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.colors as mcolors
import json
from branca.element import MacroElement
from jinja2 import Template

gdf_quartiere = gpd.read_file("data/Quartiere/2024_Quartiere.gpkg").to_crs(4326)
gdf_ortsteile = gpd.read_file("data/ortsteile_brandenburg.json", bbox=CITY_BOUNDING_BOX).to_crs(4326)
gdf_ortsteile.drop(columns=["otl_aktualitaet"], inplace=True, errors="ignore")



def get_cluster_colors(n_clusters, palette):
    return {i: palette[i % len(palette)] for i in range(n_clusters)}


def adjust_hex(hex_color, factor=1.0):
    rgb = np.array(mcolors.to_rgb(hex_color))
    if factor >= 1:
        adjusted = 1 - (1 - rgb) / factor
    else:
        adjusted = rgb * factor
    return mcolors.to_hex(np.clip(adjusted, 0, 1))


def get_cluster_colors_from_series(series, palette):
    valid = pd.Series(series).dropna().astype(int)
    if valid.empty:
        return {}
    colors = get_cluster_colors(max(valid.max() + 1, DEFAULT_CLUSTER_COUNT), palette=palette)
    return {cluster_id: colors[cluster_id] for cluster_id in sorted(valid.unique())}


def enrich_cluster_map_addresses(gdf_map):
    gdf_local = gdf_map.to_crs(4326).copy()
    gdf_local = gdf_local.drop(
        columns=["index_right", "mietkatego", "mietkategorie", "bezeichnun", "quartier", "ortsteil"],
        errors="ignore",
    )
    cols_to_drop = [col for col in gdf_local.columns if col.endswith("_quartier")]
    gdf_local = gdf_local.drop(columns=cols_to_drop, errors="ignore")
    gdf_local = gpd.sjoin(
        gdf_local,
        gdf_quartiere[["bezeichnun", "mietkatego", "geometry"]],
        how="left",
        predicate="within",
    )
    gdf_local = gdf_local.drop(columns=["index_right", "otl_name", "index_left", "otl_name_left", "otl_name_right"], errors="ignore")
    gdf_local = gpd.sjoin(
        gdf_local,
        gdf_ortsteile[["otl_name", "geometry"]],
        how="left",
        predicate="within",
    )
    gdf_local = gdf_local.drop(columns=["index_right"], errors="ignore")
    gdf_local = gdf_local.rename(columns={
        "otl_name": "ortsteil",
        "bezeichnun": "quartier",
        "mietkatego": "mietkategorie",
    })
    return gdf_local


def format_metric(value, digits=1, suffix=""):
    if pd.isna(value):
        return "unbekannt"
    try:
        return f"{float(value):.{digits}f}{suffix}"
    except Exception:
        return str(value)



def parse_route_linestring(geojson_raw):
    if geojson_raw is None:
        return None
    if isinstance(geojson_raw, float) and np.isnan(geojson_raw):
        return None
    if isinstance(geojson_raw, dict):
        geo = geojson_raw
    elif isinstance(geojson_raw, str) and geojson_raw.strip():
        try:
            geo = json.loads(geojson_raw)
        except Exception:
            return None
    else:
        return None

    if geo.get("type") == "Feature":
        geo = geo.get("geometry") or {}
    if geo.get("type") != "LineString":
        return None

    coords = []
    for coord in geo.get("coordinates", []):
        if len(coord) < 2:
            continue
        lon, lat = coord[:2]
        try:
            coords.append([round(float(lat), 6), round(float(lon), 6)])
        except Exception:
            continue
    return coords if len(coords) >= 2 else None


def build_address_route_payload(row):
    routes = []
    for cfg in POI_ROUTE_CONFIGS:
        coords = parse_route_linestring(row.get(cfg["route_col"]))
        if not coords:
            continue

        distance = row.get(cfg["distance_col"])
        distance_text = ""
        if pd.notna(distance):
            try:
                distance_text = f"{int(round(float(distance)))} m"
            except Exception:
                distance_text = str(distance)

        target = ""
        if cfg.get("target_col"):
            target = s(row.get(cfg["target_col"]))
        label = f"{cfg['label']}: {target}" if target else cfg["label"]

        routes.append({
            "coords": coords,
            "label": label,
            "distanceText": distance_text,
            "color": cfg["color"],
            "markerColor": cfg["marker_color"],
            "icon": cfg["icon"],
            "fallback": cfg["fallback"],
        })
    return routes


def build_route_lookup(gdf_local):
    lookup = {}
    for _, row in gdf_local.iterrows():
        address_id = row.get("address_id")
        if pd.isna(address_id):
            continue
        routes = build_address_route_payload(row)
        if routes:
            lookup[str(int(address_id))] = routes
    return lookup


def add_map_script(parent, script):
    macro = MacroElement()
    macro._template = Template("{% macro script(this, kwargs) %}\n" + script + "\n{% endmacro %}")
    parent.add_child(macro)
    return macro


def add_poi_route_interaction(m, route_lookup):
    route_lookup_json = json.dumps(route_lookup, ensure_ascii=False, separators=(",", ":"))
    map_name = m.get_name()
    js_name = f"{map_name}_showPoiRoutes"
    lookup_name = f"{map_name}_poiRouteLookup"
    route_layer_name = f"{map_name}_selectedPoiRoutes"
    script = f"""
    (function() {{
      var mapObj = {map_name};
      window.{lookup_name} = {route_lookup_json};
      window.{route_layer_name} = L.featureGroup().addTo(mapObj);
      var infoControl = L.control({{position: 'topright'}});
      infoControl.onAdd = function() {{
        var div = L.DomUtil.create('div', 'poi-route-info');
        div.style.background = 'white';
        div.style.padding = '8px 10px';
        div.style.border = '1px solid #999';
        div.style.borderRadius = '4px';
        div.style.fontSize = '12px';
        div.style.maxWidth = '280px';
        div.style.boxShadow = '0 1px 4px rgba(0,0,0,0.2)';
        div.innerHTML = 'Adresse anklicken, um Wege zu POIs zu zeigen.';
        return div;
      }};
      infoControl.addTo(mapObj);
      var infoDiv = infoControl.getContainer();

      function escapeHtml(value) {{
        return String(value || '').replace(/[&<>\\"']/g, function(ch) {{
          return {{'&':'&amp;','<':'&lt;','>':'&gt;','\\"':'&quot;',"'":'&#39;'}}[ch];
        }});
      }}

      function routeLabel(route) {{
        return route.label + (route.distanceText ? ' - ' + route.distanceText : '');
      }}

      function routeIcon(route) {{
        if (L.AwesomeMarkers) {{
          return L.AwesomeMarkers.icon({{
            icon: route.icon,
            prefix: 'fa',
            markerColor: route.markerColor,
            iconColor: 'white'
          }});
        }}
        return L.divIcon({{
          className: 'poi-route-marker',
          html: '<div style="width:26px;height:26px;border-radius:50%;background:' + route.color + ';color:white;border:2px solid white;box-shadow:0 1px 4px rgba(0,0,0,0.35);display:flex;align-items:center;justify-content:center;font-weight:700;font-size:12px;">' + escapeHtml(route.fallback) + '</div>',
          iconSize: [26, 26],
          iconAnchor: [13, 13]
        }});
      }}

      window.{js_name} = function(addressId, addressLabel, startLatLng) {{
        var routes = window.{lookup_name}[String(addressId)] || [];
        window.{route_layer_name}.clearLayers();
        if (routes.length === 0) {{
          infoDiv.innerHTML = '<b>' + escapeHtml(addressLabel) + '</b><br>Keine Routendaten vorhanden.';
          return;
        }}

        if (startLatLng) {{
          L.circleMarker(startLatLng, {{
            radius: 6,
            color: '#111827',
            weight: 2,
            fillColor: '#ffffff',
            fillOpacity: 1
          }}).bindTooltip('Ausgewählte Adresse: ' + addressLabel).addTo(window.{route_layer_name});
        }}

        var items = [];
        routes.forEach(function(route) {{
          if (!route.coords || route.coords.length < 2) return;
          L.polyline(route.coords, {{
            color: route.color,
            weight: 4,
            opacity: 0.9
          }}).bindTooltip(routeLabel(route)).addTo(window.{route_layer_name});

          var end = route.coords[route.coords.length - 1];
          L.marker(end, {{icon: routeIcon(route)}})
            .bindTooltip(routeLabel(route))
            .addTo(window.{route_layer_name});
          items.push('<div><span style="display:inline-block;width:10px;height:10px;background:' + route.color + ';margin-right:6px;"></span>' + escapeHtml(routeLabel(route)) + '</div>');
        }});

        infoDiv.innerHTML = '<b>' + escapeHtml(addressLabel) + '</b><br>' + items.join('');
        var bounds = window.{route_layer_name}.getBounds();
        if (bounds.isValid()) {{
          mapObj.fitBounds(bounds.pad(0.08), {{maxZoom: 16}});
        }}
      }};
    }})();
    """
    add_map_script(m, script)


def attach_poi_route_click(m, marker, row):
    address_id = row.get("address_id")
    if pd.isna(address_id):
        return
    address_label = f"{s(row.get('Straßenname'))} {s(row.get('Hsnr'))}{s(row.get('HsnrZus'))}".strip()
    if not address_label:
        address_label = s(row.get("Adresse_merge")) or f"Adresse {int(address_id)}"
    map_name = m.get_name()
    js_name = f"{map_name}_showPoiRoutes"
    script = f"""
    {marker.get_name()}.on('click', function(e) {{
      window.{js_name}({json.dumps(str(int(address_id)))}, {json.dumps(address_label, ensure_ascii=False)}, e.latlng);
    }});
    """
    add_map_script(marker, script)


def build_address_tooltip(row, cluster_col, cluster_label):
    return folium.Tooltip(
        f"""
        <div style="min-width:220px; max-width:320px; font-size:12px;">
          <div><b>{row.get('Straßenname', '')} {row.get('Hsnr', '')}</b></div>
          <div><b>{cluster_label}:</b> {format_metric(row.get(cluster_col), 0)}</div>
          <div><b>Gesamt:</b> {format_metric(row.get('score_total_scaled'))}</div>
          <div><b>Zentralität:</b> {format_metric(row.get('score_zentralitaet_scaled'))}</div>
          <div><b>Versorgung:</b> {format_metric(row.get('score_versorgung_scaled'))}</div>
          <div><b>Mobilität:</b> {format_metric(row.get('score_mobilitaet_scaled'))}</div>
          <div><b>Lärm:</b> {format_metric(row.get('score_umwelt_diagnose_scaled'))}</div>
        </div>
        """,
        sticky=True,
    )


def add_quartier_layers(m):
    folium.GeoJson(
        gdf_ortsteile,
        name="Ortsteile",
        show=False,
        style_function=lambda feature: {
            "fillColor": "#D9DEE2",
            "color": "#6B7785",
            "weight": 1.2,
            "fillOpacity": 0.04,
        },
        tooltip=folium.GeoJsonTooltip(
            fields=["otl_name"],
            aliases=["Ortsteil"],
            localize=True,
            sticky=True,
        ),
    ).add_to(m)
    folium.GeoJson(
        gdf_quartiere,
        name="Quartiere / Mietkategorien",
        show=True,
        style_function=lambda feature: {
            "fillColor": "#EFE7DC",
            "color": "#8D7B68",
            "weight": 1.6,
            "fillOpacity": 0.08,
        },
        tooltip=folium.GeoJsonTooltip(
            fields=["bezeichnun", "mietkatego"],
            aliases=["Quartier", "Mietkategorie"],
            localize=True,
            sticky=True,
        ),
    ).add_to(m)




def add_freistehend_building_layer(m, gdf_local, show=False):
    layer = folium.FeatureGroup(name="Freistehende Gebäude", show=show)
    if "is_freistehend_building" not in gdf_local.columns:
        layer.add_to(m)
        return layer

    is_freistehend = gdf_local["is_freistehend_building"].fillna(False).astype(bool)
    points = gdf_local[
        gdf_local["lat"].notna()
        & gdf_local["lon"].notna()
        & is_freistehend
    ].copy()
    for _, row in points.iterrows():
        marker = folium.CircleMarker(
            location=[row.lat, row.lon],
            radius=4,
            color=FREISTEHEND_LAYER_COLOR,
            fill=True,
            fill_color=FREISTEHEND_LAYER_COLOR,
            fill_opacity=0.9,
            weight=1,
            tooltip=build_address_tooltip(row, cluster_col="cluster_skater_block", cluster_label="SKATER-Cluster"),
        ).add_to(layer)
        if ENABLE_POI_ROUTES_IN_CLUSTER_MAPS:
            attach_poi_route_click(m, marker, row)
    layer.add_to(m)
    return layer


def add_address_cluster_layer(m, gdf_local, cluster_col, layer_name, colors, show=False):
    layer = folium.FeatureGroup(name=layer_name, show=show)
    points = gdf_local[gdf_local["lat"].notna() & gdf_local["lon"].notna() & gdf_local[cluster_col].notna()].copy()
    if points.empty:
        layer.add_to(m)
        return layer

    points[cluster_col] = points[cluster_col].astype(int)
    if "is_freistehend_building" in points.columns:
        points["is_freistehend_building"] = points["is_freistehend_building"].fillna(False)

    for _, row in points.iterrows():
        base = colors.get(int(row[cluster_col]), "#666666")
        marker_color = base
        marker_radius = 3
        tooltip = build_address_tooltip(
            row,
            cluster_col=cluster_col,
            cluster_label="Clusternummer",
        )
        marker = folium.CircleMarker(
            location=[row.lat, row.lon],
            radius=marker_radius,
            color=marker_color,
            fill=True,
            fill_color=marker_color,
            fill_opacity=0.95,
            weight=1,
            tooltip=tooltip,
        ).add_to(layer)
        if ENABLE_POI_ROUTES_IN_CLUSTER_MAPS:
            attach_poi_route_click(m, marker, row)

    layer.add_to(m)
    return layer


def add_block_polygon_layer(m, gdf_blocks_local, cluster_col, layer_name, colors, show=False):
    if gdf_blocks_local.empty:
        return None
    gdf_blocks_local = gdf_blocks_local.copy()
    gdf_blocks_local[cluster_col] = gdf_blocks_local[cluster_col].astype(int)
    folium.GeoJson(
        gdf_blocks_local,
        name=layer_name,
        show=show,
        style_function=lambda feature: {
            "fillColor": colors.get(feature["properties"][cluster_col], "#999999"),
            "color": adjust_hex(colors.get(feature["properties"][cluster_col], "#666666"), 0.55),
            "weight": 1.8,
            "fillOpacity": 0.28,
        },
        tooltip=folium.GeoJsonTooltip(
            fields=["block", "address_count", cluster_col],
            aliases=["Block", "Adressen", "Cluster"],
            localize=True,
            sticky=True,
        ),
    ).add_to(m)
    return m


def add_unclusterable_block_layer(m, gdf_blocks_local, show=True):
    if gdf_blocks_local is None or gdf_blocks_local.empty:
        return None
    gdf_blocks_local = gdf_blocks_local.to_crs(4326).copy()
    tooltip_fields = [
        col
        for col in ["block", "address_count", "skater_unclusterable_reason", "missing_features"]
        if col in gdf_blocks_local.columns
    ]
    tooltip_aliases = {
        "block": "Block",
        "address_count": "Adressen",
        "skater_unclusterable_reason": "Grund",
        "missing_features": "Fehlende Features",
    }
    folium.GeoJson(
        gdf_blocks_local,
        name="Blöcke ohne Adressen",
        show=show,
        style_function=lambda feature: {
            "fillColor": "#d73027",
            "color": "#d73027",
            "weight": 2.5,
            "fillOpacity": 0,
            "dashArray": "6,4",
        },
        tooltip=folium.GeoJsonTooltip(
            fields=tooltip_fields,
            aliases=[tooltip_aliases[col] for col in tooltip_fields],
            localize=True,
            sticky=True,
        ) if tooltip_fields else None,
    ).add_to(m)
    return m


def build_cluster_map(gdf_map, gdf_blocks_map, meta):
    gdf_local = enrich_cluster_map_addresses(gdf_map)
    m = folium.Map(location=CITY_CENTER, zoom_start=13, tiles="cartodbpositron")
    if ENABLE_POI_ROUTES_IN_CLUSTER_MAPS:
        add_poi_route_interaction(m, build_route_lookup(gdf_local))
    add_quartier_layers(m)

    skater_block_colors = get_cluster_colors_from_series(gdf_local["cluster_skater_block"], SKATER_PALETTE)
    block_skater_regions = gdf_blocks_map.to_crs(4326).copy()

    add_block_polygon_layer(
        m,
        block_skater_regions,
        cluster_col="cluster_skater_block",
        layer_name=f"SKATER Blöcke (Flächen, k={meta['n_clusters']}, {meta['block_weights_label']})",
        colors=skater_block_colors,
        show=True,
    )
    add_unclusterable_block_layer(m, gdf_blocks_unclusterable, show=True)

    add_address_cluster_layer(
        m,
        gdf_local,
        cluster_col="cluster_skater_block",
        layer_name=f"SKATER Blöcke (Adressen, k={meta['n_clusters']})",
        colors=skater_block_colors,
        show=True,
    )

    add_freistehend_building_layer(m, gdf_local, show=False)

    folium.LayerControl(collapsed=False).add_to(m)
    return m, block_skater_regions


cluster_map_outputs = []
for n_clusters in CLUSTER_EXPORT_RANGE:
    if n_clusters == DEFAULT_CLUSTER_COUNT:
        gdf_map, gdf_blocks_map, meta = gdf, gdf_blocks_skater, skater_meta
    else:
        gdf_map, gdf_blocks_map, meta = compile_cluster_results(n_clusters, verbose=False)
    m_cluster, gdf_blocks_skater_export = build_cluster_map(gdf_map, gdf_blocks_map, meta)
    html_path = MAP_EXPORT_TEMPLATE.format(n_clusters=n_clusters)
    m_cluster.save(html_path)
    cluster_map_outputs.append((n_clusters, meta["block_weights_label"], html_path))

for n_clusters, block_weights_label, html_path in cluster_map_outputs:
    print(
        f"Karte erzeugt: k={n_clusters}, Block-SKATER={block_weights_label}, file={html_path}"
    )

# Keine Inline-Kartendarstellung im Notebook. Die Karten liegen als HTML-Dateien in maps/.
# Out:
# /home/nitze/PycharmProjects/WohnlagenBRB/.venv1/lib/python3.12/site-packages/libpysal/weights/contiguity.py:61: UserWarning: The weights matrix is not fully connected:
#  There are 2 disconnected components.
#  There is 1 island with id: 561.
#   W.__init__(self, neighbors, ids=ids, **kw)
# /home/nitze/PycharmProjects/WohnlagenBRB/.venv1/lib/python3.12/site-packages/libpysal/weights/weights.py:1296: UserWarning: The weights matrix is not fully connected:
#  There are 2 disconnected components.
#  There is 1 island with id: 561.
#   out_w = W(neighbors, weights, id_order=self.id_order)
# /home/nitze/PycharmProjects/WohnlagenBRB/.venv1/lib/python3.12/site-packages/libpysal/weights/contiguity.py:61: UserWarning: The weights matrix is not fully connected:
#  There are 2 disconnected components.
#  There is 1 island with id: 561.
#   W.__init__(self, neighbors, ids=ids, **kw)
# ...

# %% [markdown]
# # Export-Pipeline
# Zum Abschluss werden die berechneten Adressdaten, Scores, Cluster, Blockregionen und Zusatzlayer als GeoPackage und CSV nach `out/` exportiert.

# %%
# Save GeoDataFrame with scores and clusters as CSV

os.makedirs(EXPORT_PATH, exist_ok=True)

if os.path.exists(EXPORT_GPKG):
    os.remove(EXPORT_GPKG)
    print(f"Alte Datei geloescht: {EXPORT_GPKG}")


def write_layer(gdf_layer, layer_name, crs=EPSG_4326):
    if gdf_layer is None or len(gdf_layer) == 0:
        print(f"Layer '{layer_name}' uebersprungen: leer oder None")
        return

    if gdf_layer.crs is None:
        print(f"GDF '{layer_name}' hat kein CRS - setze auf {crs}")
        gdf_layer = gdf_layer.set_crs(crs)
    elif gdf_layer.crs.to_string() != crs:
        print(f"Reprojiziere '{layer_name}' nach {crs}")
        gdf_layer = gdf_layer.to_crs(crs)

    gdf_layer.to_file(EXPORT_GPKG, layer=layer_name, driver="GPKG")
    print(f"Exportiert: {layer_name} -> {EXPORT_GPKG}")


export_gdf = gdf.to_crs(EPSG_4326).copy()
gdf_blocks_skater_export = gdf_blocks_skater

export_layers = {
    "wohnadressen": export_gdf,
    "wohnlagen_score": export_gdf[[col for col in export_gdf.columns if col.startswith("score_") or col in ["z_noise_penalty", "z_rail_penalty", "z_laerm_index_tag", "behind_rail_from_center", "geometry"]]],
    "cluster_skater": export_gdf[["cluster_skater", "geometry"]] if "cluster_skater" in export_gdf.columns else None,
    "cluster_skater_block": export_gdf[["cluster_skater_block", "geometry"]] if "cluster_skater_block" in export_gdf.columns else None,
    "lageklassen": export_gdf[["lageklasse", "score_total", "geometry"]] if "lageklasse" in export_gdf.columns else None,
    "block_skater_regions": gdf_blocks_skater_export[["block", "address_count", "cluster_skater_block", "geometry"]] if gdf_blocks_skater_export is not None else None,
    "bahnlinien": rails,
    "haltestellen": gdf_haltestellen if 'gdf_haltestellen' in globals() else None,
}

print("Exportiere alle Layer ...\n")
for layer_name, layer_gdf in export_layers.items():
    write_layer(layer_gdf, layer_name)

print("\nFertig. Die GeoPackage-Datei liegt hier:")
print(EXPORT_GPKG)
export_csv = export_gdf.drop(columns=["geometry"], errors="ignore")
export_csv.to_csv(EXPORT_CSV, index=False, encoding="utf-8")
print(f"CSV exportiert: {EXPORT_CSV}")
# Out:
# Alte Datei geloescht: out/wohnlagen_brb_2026.gpkg
# Exportiere alle Layer ...
#
# Exportiert: wohnadressen -> out/wohnlagen_brb_2026.gpkg
# Exportiert: wohnlagen_score -> out/wohnlagen_brb_2026.gpkg
# Exportiert: cluster_skater -> out/wohnlagen_brb_2026.gpkg
# Exportiert: cluster_skater_block -> out/wohnlagen_brb_2026.gpkg
# Layer 'lageklassen' uebersprungen: leer oder None
# Reprojiziere 'block_skater_regions' nach EPSG:4326
# Exportiert: block_skater_regions -> out/wohnlagen_brb_2026.gpkg
# Exportiert: bahnlinien -> out/wohnlagen_brb_2026.gpkg
# Exportiert: haltestellen -> out/wohnlagen_brb_2026.gpkg
#
# Fertig. Die GeoPackage-Datei liegt hier:
# out/wohnlagen_brb_2026.gpkg
# CSV exportiert: out/wohnlagen_brb_2026.csv
